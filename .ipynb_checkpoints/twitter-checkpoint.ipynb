# %%
import pandas as pd

# %%
df1=pd.read_csv("../largedata/new_range/twitter/reply_count.csv")
df1
# Out:
#               uid  reply_count
# 0        25073877       916124
# 1         1917731        78433
# 2         2836421        69368
# 3          759251        61265
# 4        39344374        56982
# ...           ...          ...
# 601967  255599274            1
# 601968  165539787            1
# 601969   60034595            1
# 601970  165542397            1
# 601971  245294597            1
#
# [601972 rows x 2 columns]

# %%
df1.rename(columns={'uid': 'user_id'}, inplace=True)

# %%
df2=pd.read_csv("../largedata/new_range/twitter/quote_count_new.csv")
df2
# Out:
#                uid  quote_count
# 0         25073877       515214
# 1          1917731        97085
# 2        288277167        68760
# 3        592730371        65218
# 4         32871086        64370
# ...            ...          ...
# 324095  1933473283            1
# 324096  1933666890            1
# 324097  1933829276            1
# 324098  1934191514            1
# 324099  1934232848            1
#
# [324100 rows x 2 columns]

# %%
df2.rename(columns={'uid': 'user_id'}, inplace=True)

# %%
df2
# Out:
#            user_id  quote_count
# 0         25073877       515214
# 1          1917731        97085
# 2        288277167        68760
# 3        592730371        65218
# 4         32871086        64370
# ...            ...          ...
# 324095  1933473283            1
# 324096  1933666890            1
# 324097  1933829276            1
# 324098  1934191514            1
# 324099  1934232848            1
#
# [324100 rows x 2 columns]

# %%
df1
# Out:
#           user_id  reply_count
# 0        25073877       916124
# 1         1917731        78433
# 2         2836421        69368
# 3          759251        61265
# 4        39344374        56982
# ...           ...          ...
# 601967  255599274            1
# 601968  165539787            1
# 601969   60034595            1
# 601970  165542397            1
# 601971  245294597            1
#
# [601972 rows x 2 columns]

# %%
merged_df = pd.merge(df1, df2, on='user_id', how='outer')
merged_df
# Fill NaN values with 0
# merged_df = merged_df.fillna(0)
# Out:
#            user_id  reply_count  quote_count
# 0         25073877     916124.0     515214.0
# 1          1917731      78433.0      97085.0
# 2          2836421      69368.0      34677.0
# 3           759251      61265.0      41295.0
# 4         39344374      56982.0      49096.0
# ...            ...          ...          ...
# 666186  1933259448          NaN          1.0
# 666187  1933363832          NaN          1.0
# 666188  1933473283          NaN          1.0
# 666189  1933666890          NaN          1.0
# 666190  1934191514          NaN          1.0
#
# [666191 rows x 3 columns]

# %%
merged_df
# Out:
#            user_id  reply_count  quote_count
# 0         25073877     916124.0     515214.0
# 1          1917731      78433.0      97085.0
# 2          2836421      69368.0      34677.0
# 3           759251      61265.0      41295.0
# 4         39344374      56982.0      49096.0
# ...            ...          ...          ...
# 666186  1933259448          NaN          1.0
# 666187  1933363832          NaN          1.0
# 666188  1933473283          NaN          1.0
# 666189  1933666890          NaN          1.0
# 666190  1934191514          NaN          1.0
#
# [666191 rows x 3 columns]

# %%
df1=pd.read_csv("../largedata/new_range/twitter/status_count.csv")
df1
# Out:
#                     user_id  status_count
# 0                 374729426         12645
# 1       1225793633342935043          8600
# 2                  49404200          6413
# 3                 226310002          6249
# 4        772464604253302784          5141
# ...                     ...           ...
# 723876             54931776             1
# 723877             54929819             1
# 723878             54925321             1
# 723879             68146152             1
# 723880            130363534             1
#
# [723881 rows x 2 columns]

# %%
df1
# Out:
#                     user_id  status_count
# 0                 374729426         12645
# 1       1225793633342935043          8600
# 2                  49404200          6413
# 3                 226310002          6249
# 4        772464604253302784          5141
# ...                     ...           ...
# 723876             54931776             1
# 723877             54929819             1
# 723878             54925321             1
# 723879             68146152             1
# 723880            130363534             1
#
# [723881 rows x 2 columns]

# %%
df=merged_df
df
# Out:
#            user_id  reply_count  quote_count
# 0         25073877     916124.0     515214.0
# 1          1917731      78433.0      97085.0
# 2          2836421      69368.0      34677.0
# 3           759251      61265.0      41295.0
# 4         39344374      56982.0      49096.0
# ...            ...          ...          ...
# 666186  1933259448          NaN          1.0
# 666187  1933363832          NaN          1.0
# 666188  1933473283          NaN          1.0
# 666189  1933666890          NaN          1.0
# 666190  1934191514          NaN          1.0
#
# [666191 rows x 3 columns]

# %%
merged_df = pd.merge(df, df1, on='user_id', how='outer')
merged_df
# Out:
#          user_id  reply_count  quote_count  status_count
# 0       25073877     916124.0     515214.0          89.0
# 1        1917731      78433.0      97085.0        3014.0
# 2        2836421      69368.0      34677.0        1126.0
# 3         759251      61265.0      41295.0         693.0
# 4       39344374      56982.0      49096.0          38.0
# ...          ...          ...          ...           ...
# 963010  96078373          NaN          NaN           1.0
# 963011  54933924          NaN          NaN           1.0
# 963012  96082623          NaN          NaN           1.0
# 963013  54929819          NaN          NaN           1.0
# 963014  54925321          NaN          NaN           1.0
#
# [963015 rows x 4 columns]

# %%
df=merged_df
df
# Out:
#          user_id  reply_count  quote_count  status_count
# 0       25073877     916124.0     515214.0          89.0
# 1        1917731      78433.0      97085.0        3014.0
# 2        2836421      69368.0      34677.0        1126.0
# 3         759251      61265.0      41295.0         693.0
# 4       39344374      56982.0      49096.0          38.0
# ...          ...          ...          ...           ...
# 963010  96078373          NaN          NaN           1.0
# 963011  54933924          NaN          NaN           1.0
# 963012  96082623          NaN          NaN           1.0
# 963013  54929819          NaN          NaN           1.0
# 963014  54925321          NaN          NaN           1.0
#
# [963015 rows x 4 columns]

# %%
df[df["status_count"].isna()&df["quote_count"].isna()&df["reply_count"].isna()]
# Out:
# Empty DataFrame
# Columns: [user_id, reply_count, quote_count, status_count]
# Index: []

# %%
import numpy as np
columns_to_check = ["reply_count","status_count","quote_count"]

for column in columns_to_check:
    if np.isinf(df[column]).any():
        print(f"Column {column} contains infinite values")


for column in columns_to_check:
    zero_count = (df[column] == 0).sum()
    if zero_count > 0:
        print(f"Column {column} contains {zero_count} zero values")

for column in columns_to_check:
    nan_count = df[column].isna().sum()
    if nan_count > 0:
        print(f"Column {column} contains {nan_count} NaN values")

for column in columns_to_check:
    negative = df[column]<0
    a=negative.sum()
    print(f"Column {column} contains {a} negative values")
# Out:
# Column reply_count contains 361043 NaN values
# Column status_count contains 239134 NaN values
# Column quote_count contains 638915 NaN values
# Column reply_count contains 0 negative values
# Column status_count contains 0 negative values
# Column quote_count contains 0 negative values

# %%
df
# Out:
#          user_id  reply_count  quote_count  status_count
# 0       25073877     916124.0     515214.0          89.0
# 1        1917731      78433.0      97085.0        3014.0
# 2        2836421      69368.0      34677.0        1126.0
# 3         759251      61265.0      41295.0         693.0
# 4       39344374      56982.0      49096.0          38.0
# ...          ...          ...          ...           ...
# 963010  96078373          NaN          NaN           1.0
# 963011  54933924          NaN          NaN           1.0
# 963012  96082623          NaN          NaN           1.0
# 963013  54929819          NaN          NaN           1.0
# 963014  54925321          NaN          NaN           1.0
#
# [963015 rows x 4 columns]

# %%
df1=pd.read_csv("../Naman/final_csv/user_data_twitter.csv")
df1
# Out:
#                 id             tweet_id              user_id user_screen_name  \
# 0        200594014  1330263124721737729                   41              drx
# 1        186732678  1331107649123971074                   57           SarahM
# 2        152714043  1334230798036164609                  224         davepell
# 3        156812061  1334574567969308674                  291          goldman
# 4        152104129  1334179632166416387                  324      chrisfralic
# ...            ...                  ...                  ...              ...
# 1715001  158561819  1334721351257612289  1334714486176051200    LarraySoThicc
# 1715002  158697103  1334732697512660992  1334719596956409858  LydiaFe71731620
# 1715003  158744538  1334736677856661507  1334721974610739203  JesusCh32131944
# 1715004  158599052  1334724472553795586  1334722394339028992   Edward18990382
# 1715005  158760754  1334738037188808704  1334727465734971392      PjTrump2020
#
# ...

# %%
df1=df1[["user_id","followers_count","friends_count"]]
df1
# Out:
#                      user_id  followers_count  friends_count
# 0                         41              102             76
# 1                         57            18097           1536
# 2                        224            57628            898
# 3                        291           960319            428
# 4                        324            32007           6436
# ...                      ...              ...            ...
# 1715001  1334714486176051200                6             39
# 1715002  1334719596956409858                0             13
# 1715003  1334721974610739203                3            110
# 1715004  1334722394339028992                0              0
# 1715005  1334727465734971392                0              0
#
# [1715006 rows x 3 columns]

# %%
merged_df = pd.merge(df, df1, on='user_id', how='inner')
merged_df
# Out:
#          user_id  reply_count  quote_count  status_count  followers_count  \
# 0       25073877     916124.0     515214.0          89.0         88767965
# 1        1917731      78433.0      97085.0        3014.0          4047510
# 2        2836421      69368.0      34677.0        1126.0          3890174
# 3         759251      61265.0      41295.0         693.0         51286169
# 4       39344374      56982.0      49096.0          38.0          6465590
# ...          ...          ...          ...           ...              ...
# 963010  96078373          NaN          NaN           1.0              209
# 963011  54933924          NaN          NaN           1.0              505
# 963012  96082623          NaN          NaN           1.0             1177
# 963013  54929819          NaN          NaN           1.0              549
# 963014  54925321          NaN          NaN           1.0              269
#
#         friends_count
# 0                  51
# 1                 268
# ...

# %%
df=merged_df
df
# Out:
#          user_id  reply_count  quote_count  status_count  followers_count  \
# 0       25073877     916124.0     515214.0          89.0         88767965
# 1        1917731      78433.0      97085.0        3014.0          4047510
# 2        2836421      69368.0      34677.0        1126.0          3890174
# 3         759251      61265.0      41295.0         693.0         51286169
# 4       39344374      56982.0      49096.0          38.0          6465590
# ...          ...          ...          ...           ...              ...
# 963010  96078373          NaN          NaN           1.0              209
# 963011  54933924          NaN          NaN           1.0              505
# 963012  96082623          NaN          NaN           1.0             1177
# 963013  54929819          NaN          NaN           1.0              549
# 963014  54925321          NaN          NaN           1.0              269
#
#         friends_count
# 0                  51
# 1                 268
# ...

# %%
import numpy as np
columns_to_check = ["reply_count","followers_count","friends_count","status_count","quote_count"]

for column in columns_to_check:
    if np.isinf(df[column]).any():
        print(f"Column {column} contains infinite values")


for column in columns_to_check:
    zero_count = (df[column] == 0).sum()
    if zero_count > 0:
        print(f"Column {column} contains {zero_count} zero values")

for column in columns_to_check:
    nan_count = df[column].isna().sum()
    if nan_count > 0:
        print(f"Column {column} contains {nan_count} NaN values")

for column in columns_to_check:
    negative = df[column]<0
    a=negative.sum()
    print(f"Column {column} contains {a} negative values")
# Out:
# Column followers_count contains 10376 zero values
# Column friends_count contains 4263 zero values
# Column reply_count contains 361043 NaN values
# Column status_count contains 239134 NaN values
# Column quote_count contains 638915 NaN values
# Column reply_count contains 0 negative values
# Column followers_count contains 0 negative values
# Column friends_count contains 0 negative values
# Column status_count contains 0 negative values
# Column quote_count contains 0 negative values

# %%
df["user_id"].is_unique
# Out:
# True

# %%
df[df["reply_count"].isna()]
# Out:
#                     user_id  reply_count  quote_count  status_count  \
# 601972  1249560127230926848          NaN       1489.0           1.0
# 601973  1301946548394233858          NaN        478.0           9.0
# 601974   757180524775387136          NaN        424.0           NaN
# 601975  1319804679342141440          NaN        381.0           NaN
# 601976  1089105580977836032          NaN        310.0           NaN
# ...                     ...          ...          ...           ...
# 963010             96078373          NaN          NaN           1.0
# 963011             54933924          NaN          NaN           1.0
# 963012             96082623          NaN          NaN           1.0
# 963013             54929819          NaN          NaN           1.0
# 963014             54925321          NaN          NaN           1.0
#
#         followers_count  friends_count
# 601972            11516            440
# 601973               65            660
# ...

# %%
df[df["quote_count"].isna()]
# Out:
#                     user_id  reply_count  quote_count  status_count  \
# 686     1286681195682492416       1185.0          NaN           2.0
# 1126    1245971873059360768        708.0          NaN           2.0
# 1603     945173707848372225        481.0          NaN           NaN
# 1607    1250960911088615424        480.0          NaN         291.0
# 1766    1316487992542982149        430.0          NaN           NaN
# ...                     ...          ...          ...           ...
# 963010             96078373          NaN          NaN           1.0
# 963011             54933924          NaN          NaN           1.0
# 963012             96082623          NaN          NaN           1.0
# 963013             54929819          NaN          NaN           1.0
# 963014             54925321          NaN          NaN           1.0
#
#         followers_count  friends_count
# 686                 420            237
# 1126                 26            325
# ...

# %%
df[df["status_count"].isna()]
# Out:
#                     user_id  reply_count  quote_count  status_count  \
# 417                75541946       2017.0        371.0           NaN
# 550                36807657       1472.0       1400.0           NaN
# 587                43014978       1399.0        415.0           NaN
# 850     1144333281099468801        950.0        722.0           NaN
# 956                28420827        845.0        509.0           NaN
# ...                     ...          ...          ...           ...
# 666182           1932463639          NaN          1.0           NaN
# 666183           1932527707          NaN          1.0           NaN
# 666184           1932637212          NaN          1.0           NaN
# 666188           1933473283          NaN          1.0           NaN
# 666189           1933666890          NaN          1.0           NaN
#
#         followers_count  friends_count
# 417             1165694            510
# 550               63031            984
# ...

# %% [markdown]
# ## Should we keep it?

# %%
df[df["status_count"].isna()&df["quote_count"].isna()&df["reply_count"].isna()]
# Out:
# Empty DataFrame
# Columns: [user_id, reply_count, quote_count, status_count, followers_count, friends_count]
# Index: []

# %%
df[df["followers_count"]==0]
# Out:
#                     user_id  reply_count  quote_count  status_count  \
# 5197    1323210514193932288        147.0         51.0           NaN
# 5944    1331778331742666752        129.0          NaN           NaN
# 7070              533327021        109.0         27.0           5.0
# 9176    1247177774839648256         85.0          2.0          28.0
# 9192     996989046206316544         85.0          1.0           8.0
# ...                     ...          ...          ...           ...
# 959993             74234337          NaN          NaN           1.0
# 960050             86021356          NaN          NaN           1.0
# 960187             86562288          NaN          NaN           1.0
# 961358            147854627          NaN          NaN           1.0
# 962477             94158635          NaN          NaN           1.0
#
#         followers_count  friends_count
# 5197                  0              9
# 5944                  0              0
# ...

# %%
df[df["friends_count"]==0]
# Out:
#                     user_id  reply_count  quote_count  status_count  \
# 74                375721095       9277.0      28553.0          89.0
# 444     1157388784301793280       1885.0       2532.0           9.0
# 1353              405605548        577.0        492.0          21.0
# 1423              355989081        550.0       1716.0         246.0
# 1953               63578758        386.0        278.0          34.0
# ...                     ...          ...          ...           ...
# 958473             80824846          NaN          NaN           1.0
# 960138             45459281          NaN          NaN           1.0
# 960965             58243960          NaN          NaN           1.0
# 961310            127636486          NaN          NaN           1.0
# 961842             71432870          NaN          NaN           1.0
#
#         followers_count  friends_count
# 74               824702              0
# 444              104242              0
# ...

# %%
df[(df["friends_count"]==0)&(df["followers_count"]==0)]
# Out:
#                     user_id  reply_count  quote_count  status_count  \
# 5944    1331778331742666752        129.0          NaN           NaN
# 7070              533327021        109.0         27.0           5.0
# 9176    1247177774839648256         85.0          2.0          28.0
# 15339   1298618350717808641         53.0          1.0          98.0
# 22378              42355904         37.0          6.0         385.0
# ...                     ...          ...          ...           ...
# 946965           4560861313          NaN          NaN           1.0
# 947382           2810249150          NaN          NaN           1.0
# 948014           2471063725          NaN          NaN           1.0
# 948479           2781536090          NaN          NaN           1.0
# 955520            115857434          NaN          NaN           1.0
#
#         followers_count  friends_count
# 5944                  0              0
# 7070                  0              0
# ...

# %% [markdown]
# ## imputation

# %%
df
# Out:
#          user_id  reply_count  quote_count  status_count  followers_count  \
# 0       25073877     916124.0     515214.0          89.0         88767965
# 1        1917731      78433.0      97085.0        3014.0          4047510
# 2        2836421      69368.0      34677.0        1126.0          3890174
# 3         759251      61265.0      41295.0         693.0         51286169
# 4       39344374      56982.0      49096.0          38.0          6465590
# ...          ...          ...          ...           ...              ...
# 963010  96078373          NaN          NaN           1.0              209
# 963011  54933924          NaN          NaN           1.0              505
# 963012  96082623          NaN          NaN           1.0             1177
# 963013  54929819          NaN          NaN           1.0              549
# 963014  54925321          NaN          NaN           1.0              269
#
#         friends_count
# 0                  51
# 1                 268
# ...

# %%
df["reply_count"]=df["reply_count"].fillna(0)
df
# Out:
#          user_id  reply_count  quote_count  status_count  followers_count  \
# 0       25073877     916124.0     515214.0          89.0         88767965
# 1        1917731      78433.0      97085.0        3014.0          4047510
# 2        2836421      69368.0      34677.0        1126.0          3890174
# 3         759251      61265.0      41295.0         693.0         51286169
# 4       39344374      56982.0      49096.0          38.0          6465590
# ...          ...          ...          ...           ...              ...
# 963010  96078373          0.0          NaN           1.0              209
# 963011  54933924          0.0          NaN           1.0              505
# 963012  96082623          0.0          NaN           1.0             1177
# 963013  54929819          0.0          NaN           1.0              549
# 963014  54925321          0.0          NaN           1.0              269
#
#         friends_count
# 0                  51
# 1                 268
# ...

# %%
df["quote_count"]=df["quote_count"].fillna(0)
df
# Out:
#          user_id  reply_count  quote_count  status_count  followers_count  \
# 0       25073877     916124.0     515214.0          89.0         88767965
# 1        1917731      78433.0      97085.0        3014.0          4047510
# 2        2836421      69368.0      34677.0        1126.0          3890174
# 3         759251      61265.0      41295.0         693.0         51286169
# 4       39344374      56982.0      49096.0          38.0          6465590
# ...          ...          ...          ...           ...              ...
# 963010  96078373          0.0          0.0           1.0              209
# 963011  54933924          0.0          0.0           1.0              505
# 963012  96082623          0.0          0.0           1.0             1177
# 963013  54929819          0.0          0.0           1.0              549
# 963014  54925321          0.0          0.0           1.0              269
#
#         friends_count
# 0                  51
# 1                 268
# ...

# %%
df["status_count"]=df["status_count"].fillna(0)
df
# Out:
#          user_id  reply_count  quote_count  status_count  followers_count  \
# 0       25073877     916124.0     515214.0          89.0         88767965
# 1        1917731      78433.0      97085.0        3014.0          4047510
# 2        2836421      69368.0      34677.0        1126.0          3890174
# 3         759251      61265.0      41295.0         693.0         51286169
# 4       39344374      56982.0      49096.0          38.0          6465590
# ...          ...          ...          ...           ...              ...
# 963010  96078373          0.0          0.0           1.0              209
# 963011  54933924          0.0          0.0           1.0              505
# 963012  96082623          0.0          0.0           1.0             1177
# 963013  54929819          0.0          0.0           1.0              549
# 963014  54925321          0.0          0.0           1.0              269
#
#         friends_count
# 0                  51
# 1                 268
# ...

# %%
df["comments_received"]=df["reply_count"]+df["quote_count"]
df
# Out:
#          user_id  reply_count  quote_count  status_count  followers_count  \
# 0       25073877     916124.0     515214.0          89.0         88767965
# 1        1917731      78433.0      97085.0        3014.0          4047510
# 2        2836421      69368.0      34677.0        1126.0          3890174
# 3         759251      61265.0      41295.0         693.0         51286169
# 4       39344374      56982.0      49096.0          38.0          6465590
# ...          ...          ...          ...           ...              ...
# 963010  96078373          0.0          0.0           1.0              209
# 963011  54933924          0.0          0.0           1.0              505
# 963012  96082623          0.0          0.0           1.0             1177
# 963013  54929819          0.0          0.0           1.0              549
# 963014  54925321          0.0          0.0           1.0              269
#
#         friends_count  comments_received
# ...

# %%
df=df[["user_id","followers_count","friends_count","status_count","comments_received"]]
df
# Out:
#          user_id  followers_count  friends_count  status_count  \
# 0       25073877         88767965             51          89.0
# 1        1917731          4047510            268        3014.0
# 2        2836421          3890174            738        1126.0
# 3         759251         51286169           1104         693.0
# 4       39344374          6465590           1495          38.0
# ...          ...              ...            ...           ...
# 963010  96078373              209            960           1.0
# 963011  54933924              505           1093           1.0
# 963012  96082623             1177            970           1.0
# 963013  54929819              549            544           1.0
# 963014  54925321              269           3193           1.0
#
#         comments_received
# 0               1431338.0
# 1                175518.0
# 2                104045.0
# 3                102560.0
# 4                106078.0
# ...                   ...
# ...

# %%
df["ratio_friends_count_followers_count"]=df["friends_count"]/df["followers_count"]
df["ratio_status_count_comments_received"]=df["status_count"]/df["comments_received"]
df
# Out:
# /tmp/ipykernel_2784053/78723036.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ratio_friends_count_followers_count"]=df["friends_count"]/df["followers_count"]
#          user_id  followers_count  friends_count  status_count  \
# 0       25073877         88767965             51          89.0
# 1        1917731          4047510            268        3014.0
# 2        2836421          3890174            738        1126.0
# 3         759251         51286169           1104         693.0
# 4       39344374          6465590           1495          38.0
# ...          ...              ...            ...           ...
# 963010  96078373              209            960           1.0
# ...

# %%
import numpy as np
columns_to_check = ["ratio_status_count_comments_received","ratio_friends_count_followers_count"]

for column in columns_to_check:
    if np.isinf(df[column]).any():
        print(f"Column {column} contains infinite values")


for column in columns_to_check:
    zero_count = (df[column] == 0).sum()
    if zero_count > 0:
        print(f"Column {column} contains {zero_count} zero values")

for column in columns_to_check:
    nan_count = df[column].isna().sum()
    if nan_count > 0:
        print(f"Column {column} contains {nan_count} NaN values")

for column in columns_to_check:
    negative = df[column]<0
    a=negative.sum()
    print(f"Column {column} contains {a} negative values")
# Out:
# Column ratio_status_count_comments_received contains infinite values
# Column ratio_friends_count_followers_count contains infinite values
# Column ratio_status_count_comments_received contains 239134 zero values
# Column ratio_friends_count_followers_count contains 2412 zero values
# Column ratio_friends_count_followers_count contains 1851 NaN values
# Column ratio_status_count_comments_received contains 0 negative values
# Column ratio_friends_count_followers_count contains 0 negative values

# %%
df[np.isinf(df["ratio_friends_count_followers_count"])]
# Out:
#                     user_id  followers_count  friends_count  status_count  \
# 5197    1323210514193932288                0              9           0.0
# 9192     996989046206316544                0             25           8.0
# 11305   1104943291848687616                0             38           0.0
# 11562   1312229100078071809                0             20          18.0
# 12559   1119693478118723584                0           1593          87.0
# ...                     ...              ...            ...           ...
# 959993             74234337                0              5           1.0
# 960050             86021356                0             59           1.0
# 960187             86562288                0             34           1.0
# 961358            147854627                0             62           1.0
# 962477             94158635                0              2           1.0
#
#         comments_received  ratio_friends_count_followers_count  \
# ...

# %%
df[df["ratio_friends_count_followers_count"].isna()]
# Out:
#                     user_id  followers_count  friends_count  status_count  \
# 5944    1331778331742666752                0              0           0.0
# 7070              533327021                0              0           5.0
# 9176    1247177774839648256                0              0          28.0
# 15339   1298618350717808641                0              0          98.0
# 22378              42355904                0              0         385.0
# ...                     ...              ...            ...           ...
# 946965           4560861313                0              0           1.0
# 947382           2810249150                0              0           1.0
# 948014           2471063725                0              0           1.0
# 948479           2781536090                0              0           1.0
# 955520            115857434                0              0           1.0
#
#         comments_received  ratio_friends_count_followers_count  \
# ...

# %%
df["ratio_friends_count_followers_count"]=df["ratio_friends_count_followers_count"].fillna(1)
df
# Out:
#          user_id  followers_count  friends_count  status_count  \
# 0       25073877         88767965             51          89.0
# 1        1917731          4047510            268        3014.0
# 2        2836421          3890174            738        1126.0
# 3         759251         51286169           1104         693.0
# 4       39344374          6465590           1495          38.0
# ...          ...              ...            ...           ...
# 963010  96078373              209            960           1.0
# 963011  54933924              505           1093           1.0
# 963012  96082623             1177            970           1.0
# 963013  54929819              549            544           1.0
# 963014  54925321              269           3193           1.0
#
#         comments_received  ratio_friends_count_followers_count  \
# 0               1431338.0                         5.745316e-07
# 1                175518.0                         6.621355e-05
# ...

# %%
df[df["ratio_friends_count_followers_count"]==1]
# Out:
#                     user_id  followers_count  friends_count  status_count  \
# 1766    1316487992542982149                4              4           0.0
# 2441    1289235861876297729              107            107           3.0
# 3580    1318008891892928513              204            204           7.0
# 4321    1257507108540604422                3              3         126.0
# 5939     750371443490168832             9806           9806          54.0
# ...                     ...              ...            ...           ...
# 960268             59310648              150            150           1.0
# 960382             87274841               23             23           1.0
# 960990             89093724              124            124           1.0
# 962332             93697649              180            180           1.0
# 962486             44529466               17             17           1.0
#
#         comments_received  ratio_friends_count_followers_count  \
# ...

# %%
df[df["ratio_status_count_comments_received"]==1]
# Out:
#                     user_id  followers_count  friends_count  status_count  \
# 7093    1285590870717132806             4014           3448         217.0
# 8702    1291735814637064192              955            937          95.0
# 10834             949459436              951            948          76.0
# 12465   1084283686739013632              392            526          75.0
# 12957              19604028             6936           3565         126.0
# ...                     ...              ...            ...           ...
# 666157           1924396621               75            478           1.0
# 666160           1924969783              388             54           1.0
# 666175           1929659887             1251           4940           1.0
# 666179           1931514290              838            591           1.0
# 666190           1934191514           150089            637           1.0
#
#         comments_received  ratio_friends_count_followers_count  \
# ...

# %%
df[(df["ratio_status_count_comments_received"]==1)&(df["status_count"]!=1)&(df["comments_received"]!=1)]
# Out:
#                     user_id  followers_count  friends_count  status_count  \
# 7093    1285590870717132806             4014           3448         217.0
# 8702    1291735814637064192              955            937          95.0
# 10834             949459436              951            948          76.0
# 12465   1084283686739013632              392            526          75.0
# 12957              19604028             6936           3565         126.0
# ...                     ...              ...            ...           ...
# 618237  1315172259338674177               20            178           2.0
# 618247  1315947781090148352                9             59           2.0
# 618262  1316496302524436480               21            252           2.0
# 618264  1316552578449145858              249           1118           2.0
# 618277  1316938013029638145                3             44           2.0
#
#         comments_received  ratio_friends_count_followers_count  \
# ...

# %%
df[(df["ratio_status_count_comments_received"]==1)&(df["status_count"]==1)&(df["comments_received"]==1)]
# Out:
#            user_id  followers_count  friends_count  status_count  \
# 393821    36335442              523            629           1.0
# 393837    36364985               27            572           1.0
# 393838    36367628              718            559           1.0
# 393853    50257835            15469            888           1.0
# 393859    50263870             1391            765           1.0
# ...            ...              ...            ...           ...
# 666157  1924396621               75            478           1.0
# 666160  1924969783              388             54           1.0
# 666175  1929659887             1251           4940           1.0
# 666179  1931514290              838            591           1.0
# 666190  1934191514           150089            637           1.0
#
#         comments_received  ratio_friends_count_followers_count  \
# 393821                1.0                             1.202677
# ...

# %%
import numpy as np
columns_to_check = ["ratio_status_count_comments_received","ratio_friends_count_followers_count"]

for column in columns_to_check:
    if np.isinf(df[column]).any():
        print(f"Column {column} contains infinite values")


for column in columns_to_check:
    zero_count = (df[column] == 0).sum()
    if zero_count > 0:
        print(f"Column {column} contains {zero_count} zero values")

for column in columns_to_check:
    nan_count = df[column].isna().sum()
    if nan_count > 0:
        print(f"Column {column} contains {nan_count} NaN values")

for column in columns_to_check:
    negative = df[column]<0
    a=negative.sum()
    print(f"Column {column} contains {a} negative values")
# Out:
# Column ratio_status_count_comments_received contains infinite values
# Column ratio_friends_count_followers_count contains infinite values
# Column ratio_status_count_comments_received contains 239134 zero values
# Column ratio_friends_count_followers_count contains 2412 zero values
# Column ratio_status_count_comments_received contains 0 negative values
# Column ratio_friends_count_followers_count contains 0 negative values

# %% [markdown]
# # Roles with lurker

# %%
broadcaster=(df["ratio_friends_count_followers_count"]<1)&(df["ratio_status_count_comments_received"]<1)
broadcaster.sum()
# Out:
# 104675

# %%
(104675/896462)*100
# Out:
# 11.676457005428006

# %%
common_users=(df["ratio_friends_count_followers_count"]>1)&(df["ratio_status_count_comments_received"]<1)
common_users.sum()
# Out:
# 325311

# %%
(325311/896462)*100
# Out:
# 36.2883200849562

# %%
hidden_influentials=(df["ratio_friends_count_followers_count"]>1)&(df["ratio_status_count_comments_received"]>1)
hidden_influentials.sum()
# Out:
# 343150

# %%
(343150/896462)*100
# Out:
# 38.27825384678882

# %%
influentials=(df["ratio_friends_count_followers_count"]<1)&(df["ratio_status_count_comments_received"]>1)
influentials.sum()
# Out:
# 121475

# %%
(121475/896462)*100
# Out:
# 13.550490706800735

# %%
lurkers=(df["ratio_friends_count_followers_count"]==1)|(df["ratio_status_count_comments_received"]==1)
lurkers.sum()
# Out:
# 68404

# %%
(67614/963015)*100
# Out:
# 7.021074438092864

# %%
#old 
358595+1320084+6782+12081+17464
# Out:
# 1715006

# %%
104675+325311+343150+121475+68404
# Out:
# 963015

# %%
new_lurkers=(((df["followers_count"]==0)&(df["friends_count"]==0))|((df["status_count"]==0)&(df["comments_received"]==0)))
new_lurkers.sum()
# Out:
# 1851

# %%
(1854/896462)*100
# Out:
# 0.20681300490149054

# %%
total=963015+1851-68404
total
# Out:
# 896462

# %%
12.49+37.35+37.17+12.76+0.2
# Out:
# 99.97000000000001

# %%
df[(df["ratio_friends_count_followers_count"]==1)&(df["friends_count"]==0)&(df["followers_count"]==0)]
# Out:
#                      user_id  user_mentioned  followers_count  friends_count  \
# 27525               16961198             0.0                0              0
# 29223               17194447             0.0                0              0
# 38585               18678625             0.0                0              0
# 41643               19190374             2.0                0              0
# 46697               20083865             1.0                0              0
# ...                      ...             ...              ...            ...
# 1714978  1334639004336050177             0.0                0              0
# 1714998  1334691134409420801             0.0                0              0
# 1715000  1334710723453313024             0.0                0              0
# 1715004  1334722394339028992             0.0                0              0
# 1715005  1334727465734971392             0.0                0              0
#
# ...

# %%
df[(df["ratio_friends_count_followers_count"]==1)&(df["friends_count"]!=0)&(df["followers_count"]!=0)]
# Out:
#                      user_id  user_mentioned  followers_count  friends_count  \
# 862                   941781             0.0              159            159
# 1288                 1835601             1.0             4254           4254
# 2108                 4636351             0.0              161            161
# 2323                 5490192             0.0              639            639
# 4469                 8638522            12.0               99             99
# ...                      ...             ...              ...            ...
# 1714287  1333552816674267136             0.0                4              4
# 1714349  1333606939775930368             0.0                1              1
# 1714561  1333857410688065536             0.0                1              1
# 1714711  1334024640541372416             0.0                4              4
# 1714917  1334460627805495301             1.0                1              1
#
# ...

# %%
df[(df["ratio_user_mentioned_statuses_count"]==1)&(df["user_mentioned"]==0)&(df["statuses_count"]==0)]
# Out:
# Empty DataFrame
# Columns: [user_id, user_mentioned, followers_count, friends_count, statuses_count, ratio_friends_count_followers_count, ratio_user_mentioned_statuses_count]
# Index: []

# %%
df[df["user_mentioned"]==1]
# Out:
#                      user_id  user_mentioned  followers_count  friends_count  \
# 6                        509             1.0             8942           2212
# 7                        531             1.0             5854           6431
# 16                      1427             1.0             2030           3248
# 22                      1968             1.0             4915           2011
# 25                      2092             1.0              786           1579
# ...                      ...             ...              ...            ...
# 1714941  1334536690493435909             1.0                6             54
# 1714948  1334548577314611204             1.0                0             19
# 1714961  1334580124365283328             1.0               25             87
# 1714976  1334629354521944069             1.0                0             49
# 1714985  1334662902217846787             1.0                5            115
#
# ...

# %%
df[(df["ratio_user_mentioned_statuses_count"]==1)]
# Out:
#                      user_id  user_mentioned  followers_count  friends_count  \
# 42712               19367396            17.0               52            291
# 151852              54885302             8.0               55            203
# 430385             426066269             5.0              168             75
# 447716             465117268            17.0                1              1
# 677167            2240772889             7.0              233           1969
# ...                      ...             ...              ...            ...
# 1710436  1330632920747405312             2.0                0              0
# 1710897  1330899221537464320             2.0                0              4
# 1713534  1332716147402186754             1.0                0              0
# 1713799  1333017398803378176             1.0                0              2
# 1714258  1333513884129517579             1.0                0              7
#
# ...

# %%
df[(df["ratio_user_mentioned_statuses_count"]==1)&(df["user_mentioned"]!=0)&(df["statuses_count"]!=0)]
# Out:
#                      user_id  user_mentioned  followers_count  friends_count  \
# 42712               19367396            17.0               52            291
# 151852              54885302             8.0               55            203
# 430385             426066269             5.0              168             75
# 447716             465117268            17.0                1              1
# 677167            2240772889             7.0              233           1969
# ...                      ...             ...              ...            ...
# 1710436  1330632920747405312             2.0                0              0
# 1710897  1330899221537464320             2.0                0              4
# 1713534  1332716147402186754             1.0                0              0
# 1713799  1333017398803378176             1.0                0              2
# 1714258  1333513884129517579             1.0                0              7
#
# ...

# %%
## Checking common_users

# %%
df[(df["ratio_friends_count_followers_count"]>1)&(df["ratio_user_mentioned_statuses_count"]<1)]
# Out:
#                      user_id  user_mentioned  followers_count  friends_count  \
# 5                        352             3.0              588           1009
# 7                        531             1.0             5854           6431
# 16                      1427             1.0             2030           3248
# 17                      1467             0.0              555            614
# 25                      2092             1.0              786           1579
# ...                      ...             ...              ...            ...
# 1714997  1334684346599559168             0.0                1             39
# 1714999  1334708142052048897             0.0                3             66
# 1715001  1334714486176051200             3.0                6             39
# 1715002  1334719596956409858             0.0                0             13
# 1715003  1334721974610739203             0.0                3            110
#
# ...

# %%
df.to_csv("../Naman/final_csv/twitter_final.csv")

# %% [markdown]
# # Final

# %%
import pandas as pd
df1=pd.read_csv("../Naman/final_csv/tweet_data.csv")
df1
# Out:
#         in_reply_to_user_id  tweet_count    latest_tweet_time
# 0                        57            5  2020-11-22 17:57:33
# 1                       224          112  2020-12-04 04:01:03
# 2                       291           30  2020-12-03 01:58:46
# 3                       324            8  2020-12-01 18:28:15
# 4                       352            3  2020-12-02 22:07:06
# ...                     ...          ...                  ...
# 737237  1334548577314611204            1  2020-12-03 17:54:39
# 737238  1334580124365283328            1  2020-12-03 21:42:06
# 737239  1334629354521944069            1  2020-12-04 04:00:05
# 737240  1334662902217846787            1  2020-12-04 02:39:36
# 737241  1334714486176051200            3  2020-12-04 04:54:37
#
# [737242 rows x 3 columns]

# %%
import pandas as pd
df1=pd.read_csv("../Naman/final_csv/user_data_twitter.csv")
df1
# Out:
#                 id             tweet_id              user_id user_screen_name  \
# 0        200594014  1330263124721737729                   41              drx
# 1        186732678  1331107649123971074                   57           SarahM
# 2        152714043  1334230798036164609                  224         davepell
# 3        156812061  1334574567969308674                  291          goldman
# 4        152104129  1334179632166416387                  324      chrisfralic
# ...            ...                  ...                  ...              ...
# 1715001  158561819  1334721351257612289  1334714486176051200    LarraySoThicc
# 1715002  158697103  1334732697512660992  1334719596956409858  LydiaFe71731620
# 1715003  158744538  1334736677856661507  1334721974610739203  JesusCh32131944
# 1715004  158599052  1334724472553795586  1334722394339028992   Edward18990382
# 1715005  158760754  1334738037188808704  1334727465734971392      PjTrump2020
#
# ...

# %%
import pandas as pd
df=pd.read_csv("../Naman/final_csv/twitter_final.csv")
df
# Out:
#          Unnamed: 0              user_id  user_mentioned  followers_count  \
# 0                 0                   41             0.0              102
# 1                 1                   57             5.0            18097
# 2                 2                  224           112.0            57628
# 3                 3                  291            30.0           960319
# 4                 4                  324             8.0            32007
# ...             ...                  ...             ...              ...
# 1715001     1715001  1334714486176051200             3.0                6
# 1715002     1715002  1334719596956409858             0.0                0
# 1715003     1715003  1334721974610739203             0.0                3
# 1715004     1715004  1334722394339028992             0.0                0
# 1715005     1715005  1334727465734971392             0.0                0
#
#          friends_count  statuses_count  ratio_friends_count_followers_count  \
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
vv=pd.read_csv("../largedata/new_range/twitter/exp.csv")
vv
# Out:
#             id             tweet_id              user_id tweet_lang  \
# 0    180139343  1332602726019166209   731194458570670080         en
# 1    180139422  1332602732742660096             50521292         en
# 2    180139459  1332602734596419589            176995666        und
# 3    180139480  1332602737498804224   747148865527128064         en
# 4    180140064  1332602784882024449           2908841933         en
# ..         ...                  ...                  ...        ...
# 995  180333651  1332619025134755846   806282129214558208         en
# 996  180333708  1332619029824024578  1214974944066637825        und
# 997  180333830  1332619040922226692            159494523        und
# 998  180334906  1332619129908412418             56315497         en
# 999  180334932  1332619133519859712           3665198176         en
#
#               tweet_time                                             source  \
# ...
