# %% [markdown]
# # Dotwin

# %%
cc=pd.read_csv("../largedata/new_range/processed_parler_comments.csv")
cc
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [44], line 1
# ----> 1 cc=pd.read_csv("../largedata/new_range/processed_parler_comments.csv")
#       2 cc
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd

# %%
co=pd.read_pickle("../largedata/dotwin/dotwin_comments.pkl")
co
# Out:
#                    site         pid                      permalink  \
# 0        kotakuinaction    GIEZWkV7     /p/GIEZWkV7/x/c/12jw8CGTdC
# 1        kotakuinaction    GIEZWkV7     /p/GIEZWkV7/x/c/12jw8CGTxs
# 2        kotakuinaction    GIEZWkV7     /p/GIEZWkV7/x/c/12jw8CGkoX
# 3        kotakuinaction    GIEZWkV7     /p/GIEZWkV7/x/c/12jw8CGksi
# 4        kotakuinaction    GIEZWkV7     /p/GIEZWkV7/x/c/12jw8CGl0s
# ...                 ...         ...                            ...
# 1601646       thedonald  12hRCKGD22  /p/12hRCKGD22/x/c/4Dx42GGn7fk
# 1601647       thedonald  12hRCKFwJf  /p/12hRCKFwJf/x/c/4Dx42GGn7o1
# 1601648       thedonald  12hRCKFwJf  /p/12hRCKFwJf/x/c/4Dx42GGn7sE
# 1601649       thedonald  12hRCJ9jee  /p/12hRCJ9jee/x/c/4Dx42GGn7sH
# 1601650       thedonald  12hRCKFwJf  /p/12hRCKFwJf/x/c/4Dx42GGn80O
#
#                   timestamp  upvotes  downvotes               author  \
# 0       2020-06-29 22:38:43       17          3       TheWhiteFalcon
# ...

# %%
po=pd.read_pickle("../largedata/dotwin/dotwin_posts.pkl")
po
# Out:
#                   site         pid    data_id           timestamp  votes  \
# 0       kotakuinaction    GIEZWkV7   401761.0 2020-06-29 22:25:27  636.0
# 1       kotakuinaction    GIEaf8gj   402711.0 2020-06-30 01:16:57  219.0
# 2       kotakuinaction    GIEaf8oz   402731.0 2020-06-30 01:20:47  349.0
# 3       kotakuinaction    GIEaf8p2   402734.0 2020-06-30 01:21:01  572.0
# 4       kotakuinaction    GIEaf8xF   402751.0 2020-06-30 01:24:37  444.0
# ...                ...         ...        ...                 ...    ...
# 227173       thedonald  12hRCKGD22  2028242.0 2021-02-09 15:00:28    3.0
# 227174  greatawakening  12hRCKGD23  2028243.0 2021-02-09 15:00:30    2.0
# 227175       thedonald  12hRCKGD24  2028244.0 2021-02-09 15:00:50    2.0
# 227176       thedonald  12hRCKGD25  2028245.0 2021-02-09 15:01:06    1.0
# 227177  greatawakening  12hRCKGD26  2028246.0 2021-02-09 15:02:27    1.0
#
#         upvotes  downvotes        author  \
# 0         646.0       10.0    HandofBane
# ...

# %%
co= co[co['timestamp'] >= '2020-08-01']
co['year_week'] = co['timestamp'].dt.to_period('W')
co
# Out:
# /tmp/ipykernel_573838/1648338203.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co['year_week'] = co['timestamp'].dt.to_period('W')
#                   site         pid                      permalink  \
# 4986     weekendgunnit    GbotTGtV     /p/GbotTGtV/x/c/142BJfl8q5
# 4987     weekendgunnit    GborDaRt     /p/GborDaRt/x/c/142BJflPxH
# 4988     weekendgunnit    GbotTovQ     /p/GbotTovQ/x/c/142BJgtX1k
# 4989     weekendgunnit    GbomgYGR     /p/GbomgYGR/x/c/142BJgtoD1
# 4990     weekendgunnit    GbkBi6cN     /p/GbkBi6cN/x/c/142BJhzj5Z
# ...                ...         ...                            ...
# 1601646      thedonald  12hRCKGD22  /p/12hRCKGD22/x/c/4Dx42GGn7fk
# ...

# %%
co=co[["author","content","year_week"]]
co
# Out:
#                       author  \
# 4986                BigIgloo
# 4987                  Tubesy
# 4988              HonkNJhonk
# 4989                  migger
# 4990                  migger
# ...                      ...
# 1601646            KuzoKevin
# 1601647  Boilingsnowflakes4u
# 1601648           MythArcana
# 1601649            residue69
# 1601650        JenniferJames
#
#                                                    content  \
# 4986     I guess you gotta sleep with ear protection ar...
# 4987     All of my AK brakes wobble.  At this point I t...
# 4988     Yes, but what kind of meal should I cook for m...
# 4989                   Sub-Saharan IQ is a hell of a drug.
# 4990                 Blacks are essentially the Jews pets.
# ...                                                    ...
# 1601646  Link to archived article - https://archive.vn/...
# 1601647  They should have already been rounded up and p...
# 1601648  Isn't this exactly what the 1st Amendment was ...
# ...

# %% [markdown]
# ## post

# %%
po= po[po['timestamp'] >= '2020-08-01']
po['year_week'] = po['timestamp'].dt.to_period('W')
po
# Out:
# /tmp/ipykernel_573838/1698374591.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po['year_week'] = po['timestamp'].dt.to_period('W')
#                   site         pid    data_id           timestamp  votes  \
# 542      weekendgunnit    GbtUTN26   541386.0 2020-08-01 14:02:07   93.0
# 543      weekendgunnit    GbtUTurZ   541541.0 2020-08-01 14:48:34   53.0
# 544      weekendgunnit    GbtUUT1n   541753.0 2020-08-01 15:43:10   57.0
# 545      weekendgunnit    GbtVd8nT   542883.0 2020-08-01 20:09:04   77.0
# 546      weekendgunnit    GbtWlnxx   543921.0 2020-08-02 01:07:04   40.0
# ...                ...         ...        ...                 ...    ...
# 227173       thedonald  12hRCKGD22  2028242.0 2021-02-09 15:00:28    3.0
# ...

# %%
po=po[["author","title","year_week","content"]]
po
# Out:
#                  author                                              title  \
# 542      Rawnold_Reagan                                  The metric system
# 543     GarudaDarkblack                        First AR build. How'd I do?
# 544           Sunsetmal  Gunsmiths were all booked. So I said fuck it, ...
# 545                arma  TFW you need to visit the wife's son but he go...
# 546              Gewehr                          Peace was never an option
# ...                 ...                                                ...
# 227173        KuzoKevin  We, for supporting Trump, are extremists accor...
# 227174         undine53  Biden Quietly Revokes Trump’s Ban on Chinese C...
# 227175          Danleif                     Night is day. Time to wake up!
# 227176          Awshit1              Big brother is always there to protek
# 227177          MikeWho  The people complaining about too many George p...
#
#                     year_week content
# ...

# %% [markdown]
# ## users

# %%
concatenated_df = pd.concat([po,co], axis=0)
concatenated_df
# Out:
#                       author  \
# 542           Rawnold_Reagan
# 543          GarudaDarkblack
# 544                Sunsetmal
# 545                     arma
# 546                   Gewehr
# ...                      ...
# 1601646            KuzoKevin
# 1601647  Boilingsnowflakes4u
# 1601648           MythArcana
# 1601649            residue69
# 1601650        JenniferJames
#
#                                                      title  \
# 542                                      The metric system
# 543                            First AR build. How'd I do?
# 544      Gunsmiths were all booked. So I said fuck it, ...
# 545      TFW you need to visit the wife's son but he go...
# 546                              Peace was never an option
# ...                                                    ...
# 1601646                                                NaN
# 1601647                                                NaN
# 1601648                                                NaN
# ...

# %%
concatenated_df["author"].nunique()
# Out:
# 47592

# %%
unique_authors_per_week = concatenated_df.groupby('year_week')['author'].nunique()
unique_authors_df = unique_authors_per_week.reset_index(name='unique_authors')
unique_authors_df
# Out:
#                 year_week  unique_authors
# 0   2020-07-27/2020-08-02              59
# 1   2020-08-03/2020-08-09             130
# 6   2020-09-07/2020-09-13   0.031566
# 7   2020-09-14/2020-09-20   0.021858
# 8   2020-09-21/2020-09-27   0.025553
# 9   2020-09-28/2020-10-04   0.031315
# 10  2020-10-05/2020-10-11   0.021795
# 11  2020-10-12/2020-10-18   0.019165
# 12  2020-10-19/2020-10-25   0.016284
# 13  2020-10-26/2020-11-01   0.015658
# 14  2020-11-02/2020-11-08   0.035637
# 15  2020-11-09/2020-11-15   0.025741
# 16  2020-11-16/2020-11-22   0.022672
# 17  2020-11-23/2020-11-29   0.129645
# 18  2020-11-30/2020-12-06   0.123132
# 19  2020-12-07/2020-12-13   0.211190
# 20  2020-12-14/2020-12-20   1.175012
# 21  2020-12-21/2020-12-27   0.649792
# 22  2020-12-28/2021-01-03   1.246661
# 23  2021-01-04/2021-01-10  12.592184
# ...

# %%
week_counts_df_1["row_count"].sum()
# Out:
# 100.0

# %% [markdown]
# # Parlers

# %%
import pandas as pd
df=pd.read_csv("../largedata/new_range/parler_huge.csv")
df
# Out:
#            Unnamed: 0                           creator  \
# 0                   0  b998a02793634bd1b4e44ad3d0c3b232
# 1                   1  436362cdd252424a994e6eded06183cd
# 2                   2  f34f55277e02489baffc0ac0a9a0a556
# 3                   4  d780380f83884fdeb1fe2f5120ec256f
# 4                   5  653ba961088c4d1f8997599fe19c9b64
# ...               ...                               ...
# 138620026     1063295  68694fd1c9a64212879b11dbdd7fdcd2
# 138620027     1063297  6e9c1043aa944bffbda4d95406b23362
# 138620028     1063298  647c271c20e54d9c98d8c81930038b60
# 138620029     1063300  1bb963dc33384701b98932671ec2699f
# 138620030     1063301  c6a7240c441d48e8b45cf6e2b095b13e
#
#                   createdAtformatted datatype              year_week
# 0          2020-12-06 15:18:47+00:00    posts  2020-11-30/2020-12-06
# 1          2020-11-23 11:46:20+00:00    posts  2020-11-23/2020-11-29
# 2          2020-11-02 12:51:01+00:00    posts  2020-11-02/2020-11-08
# ...

# %%
print("test")
# Out:
# test

# %%
df["creator"].nunique()
# Out:
# 3456851

# %% [markdown]
# ## users

# %%
unique_authors_per_week = df.groupby('year_week')['creator'].nunique()
unique_authors_df_parler = unique_authors_per_week.reset_index(name='creator')
unique_authors_df_parler
# Out:
#                 year_week  creator
# 0   2020-07-27/2020-08-02    99198
# 1   2020-08-03/2020-08-09   174518
# 2   2020-08-10/2020-08-16   167033
# 3   2020-08-17/2020-08-23   163251
# 4   2020-08-24/2020-08-30   149861
# 5   2020-08-31/2020-09-06   204627
# 6   2020-09-07/2020-09-13   154389
# 7   2020-09-14/2020-09-20   142415
# 8   2020-09-21/2020-09-27   137994
# 9   2020-09-28/2020-10-04   150240
# 10  2020-10-05/2020-10-11   147817
# 11  2020-10-12/2020-10-18   195231
# 12  2020-10-19/2020-10-25   186381
# 13  2020-10-26/2020-11-01   188466
# 14  2020-11-02/2020-11-08   917723
# 15  2020-11-09/2020-11-15  1771119
# 16  2020-11-16/2020-11-22  1062927
# 17  2020-11-23/2020-11-29   760060
# 18  2020-11-30/2020-12-06   598952
# 19  2020-12-07/2020-12-13   532408
# 20  2020-12-14/2020-12-20   455747
# 21  2020-12-21/2020-12-27   374942
# 22  2020-12-28/2021-01-03   306388
# 23  2021-01-04/2021-01-10   620485
# 24  2021-01-11/2021-01-17    12153

# %%
unique_authors_df_parler["creator"].sum()
# Out:
# 9674325

# %%
unique_authors_df_parler["creator"]=(unique_authors_df_parler["creator"]/3456851)*100

# %%
unique_authors_df_parler
# Out:
#                 year_week    creator
# 0   2020-07-27/2020-08-02   2.869606
# 1   2020-08-03/2020-08-09   5.048468
# 2   2020-08-10/2020-08-16   4.831941
# 3   2020-08-17/2020-08-23   4.722535
# 4   2020-08-24/2020-08-30   4.335188
# 5   2020-08-31/2020-09-06   5.919463
# 6   2020-09-07/2020-09-13   4.466175
# 7   2020-09-14/2020-09-20   4.119790
# 8   2020-09-21/2020-09-27   3.991899
# 9   2020-09-28/2020-10-04   4.346152
# 10  2020-10-05/2020-10-11   4.276059
# 11  2020-10-12/2020-10-18   5.647654
# 12  2020-10-19/2020-10-25   5.391641
# 13  2020-10-26/2020-11-01   5.451956
# 14  2020-11-02/2020-11-08  26.547948
# 15  2020-11-09/2020-11-15  51.235040
# 16  2020-11-16/2020-11-22  30.748418
# 17  2020-11-23/2020-11-29  21.987063
# 18  2020-11-30/2020-12-06  17.326521
# 19  2020-12-07/2020-12-13  15.401532
# 20  2020-12-14/2020-12-20  13.183877
# 21  2020-12-21/2020-12-27  10.846345
# 22  2020-12-28/2021-01-03   8.863211
# 23  2021-01-04/2021-01-10  17.949429
# ...

# %%
unique_authors_df_parler.to_csv("../largedata/new_range/week_analysis_parler/user_parler.csv",index=False)

# %% [markdown]
# ## posts

# %%
po=df[df["datatype"]=="posts"]
po
# Out:
#            Unnamed: 0                           creator  \
# 0                   0  b998a02793634bd1b4e44ad3d0c3b232
# 1                   1  436362cdd252424a994e6eded06183cd
# 2                   2  f34f55277e02489baffc0ac0a9a0a556
# 3                   4  d780380f83884fdeb1fe2f5120ec256f
# 4                   5  653ba961088c4d1f8997599fe19c9b64
# ...               ...                               ...
# 138620026     1063295  68694fd1c9a64212879b11dbdd7fdcd2
# 138620027     1063297  6e9c1043aa944bffbda4d95406b23362
# 138620028     1063298  647c271c20e54d9c98d8c81930038b60
# 138620029     1063300  1bb963dc33384701b98932671ec2699f
# 138620030     1063301  c6a7240c441d48e8b45cf6e2b095b13e
#
#                   createdAtformatted datatype              year_week
# 0          2020-12-06 15:18:47+00:00    posts  2020-11-30/2020-12-06
# 1          2020-11-23 11:46:20+00:00    posts  2020-11-23/2020-11-29
# 2          2020-11-02 12:51:01+00:00    posts  2020-11-02/2020-11-08
# ...

# %%
week_counts = po.groupby('year_week').size()
week_counts_df_parler = week_counts.reset_index(name='row_count')
week_counts_df_parler
# Out:
#                 year_week  row_count
# 0   2020-07-27/2020-08-02     516752
# 1   2020-08-03/2020-08-09    1638504
# 2   2020-08-10/2020-08-16    1629109
# 3   2020-08-17/2020-08-23    1705399
# 16  2020-11-16/2020-11-22   9.569383
# 17  2020-11-23/2020-11-29   8.570710
# 18  2020-11-30/2020-12-06   7.381250
# 19  2020-12-07/2020-12-13   6.996423
# 20  2020-12-14/2020-12-20   6.348001
# 21  2020-12-21/2020-12-27   4.674541
# 22  2020-12-28/2021-01-03   3.289532
# 23  2021-01-04/2021-01-10   4.797914
# ...

# %%
week_counts_df_parler.to_csv("../largedata/new_range/week_analysis_parler/post_parler.csv",index=False)

# %%
week_counts_df_parler["row_count"].sum()
# Out:
# 99.99999999999999

# %% [markdown]
# ## comments

# %%
co=df[df["datatype"]=="comments"]
co
# Out:
#            Unnamed: 0                           creator  \
# 560               707  d4a1b8706ec949d3a4c17a64b136e3c0
# 561               708  800713c54d6a4bd7b7f86601c175c881
# 562               709  0db8ff7db00040db939b95bf38737073
# 563               710  71c863fbfedd4d63a3a26cf898bdab2d
# 564               711  6725899c6d9542e99932aa95e3b33557
# ...               ...                               ...
# 138602526     1039828  8de3266c4073452a97d2ea6c955f712b
# 138602527     1039829  1e2555d41f4245d293c7f5e35fee5c77
# 138602528     1039831  e5034049b6da47279a86c25ca44fb055
# 138602529     1039832  4d03d3901b884d51ae0811b21db49764
# 138602530     1039834  a2aae12a52e24f34bda8c0c2eada93ed
#
#                   createdAtformatted  datatype              year_week
# 560        2020-12-12 23:09:45+00:00  comments  2020-12-07/2020-12-13
# 561        2020-08-27 03:05:01+00:00  comments  2020-08-24/2020-08-30
# 562        2020-12-18 04:45:35+00:00  comments  2020-12-14/2020-12-20
# ...

# %%
week_counts_co = co.groupby('year_week').size()
week_counts_df_1_parler = week_counts_co.reset_index(name='row_count')
week_counts_df_1_parler
# Out:
#                 year_week  row_count
# 0   2020-07-27/2020-08-02     393668
# 1   2020-08-03/2020-08-09    1268893
# 2   2020-08-10/2020-08-16    1199591
# 3   2020-08-17/2020-08-23    1250632
# 4   2020-08-24/2020-08-30    1298370
# 5   2020-08-31/2020-09-06    1371279
# 6   2020-09-07/2020-09-13    1227386
# 7   2020-09-14/2020-09-20    1200145
# 8   2020-09-21/2020-09-27    1199259
# 9   2020-09-28/2020-10-04    1272108
# 10  2020-10-05/2020-10-11    1282796
# 11  2020-10-12/2020-10-18    1411427
# 12  2020-10-19/2020-10-25    1438652
# 13  2020-10-26/2020-11-01    1479764
# 14  2020-11-02/2020-11-08    4708995
# 15  2020-11-09/2020-11-15    9818779
# 16  2020-11-16/2020-11-22    7266374
# 17  2020-11-23/2020-11-29    5352931
# 18  2020-11-30/2020-12-06    4091635
# 19  2020-12-07/2020-12-13    4273894
# 20  2020-12-14/2020-12-20    3885832
# 21  2020-12-21/2020-12-27    2871233
# 22  2020-12-28/2021-01-03    2437428
# 23  2021-01-04/2021-01-10    3713099
# ...

# %%
week_counts_df_1_parler["row_count"].sum()
# Out:
# 65728166

# %%
week_counts_df_1_parler["row_count"]=(week_counts_df_1_parler["row_count"]/65728166)*100
week_counts_df_1_parler
# Out:
#                 year_week  row_count
# 0   2020-07-27/2020-08-02   0.598933
# 1   2020-08-03/2020-08-09   1.930516
# 2   2020-08-10/2020-08-16   1.825079
# 3   2020-08-17/2020-08-23   1.902734
# 4   2020-08-24/2020-08-30   1.975363
# 5   2020-08-31/2020-09-06   2.086288
# 6   2020-09-07/2020-09-13   1.867367
# 7   2020-09-14/2020-09-20   1.825922
# 8   2020-09-21/2020-09-27   1.824574
# 9   2020-09-28/2020-10-04   1.935408
# 10  2020-10-05/2020-10-11   1.951669
# 11  2020-10-12/2020-10-18   2.147370
# 12  2020-10-19/2020-10-25   2.188791
# 13  2020-10-26/2020-11-01   2.251339
# 14  2020-11-02/2020-11-08   7.164349
# 15  2020-11-09/2020-11-15  14.938465
# 16  2020-11-16/2020-11-22  11.055191
# 17  2020-11-23/2020-11-29   8.144044
# 18  2020-11-30/2020-12-06   6.225086
# 19  2020-12-07/2020-12-13   6.502378
# 20  2020-12-14/2020-12-20   5.911974
# 21  2020-12-21/2020-12-27   4.368345
# 22  2020-12-28/2021-01-03   3.708346
# 23  2021-01-04/2021-01-10   5.649175
# ...

# %%
week_counts_df_1_parler.to_csv("../largedata/new_range/week_analysis_parler/comment_parler.csv",index=True)

# %% [markdown]
# # Twitter

# %%
df=pd.read_csv("../largedata/new_range/tweet_with_week.csv")
df
# Out:
#             week_start             week_end  tweet_count
# 0  2020-09-28 00:00:00  2020-10-04 00:00:00     12403655
# 1  2020-10-05 00:00:00  2020-10-11 00:00:00     15789158
# 2  2020-10-12 00:00:00  2020-10-18 00:00:00     16350361
# 3  2020-10-19 00:00:00  2020-10-25 00:00:00     14413744
# 4  2020-10-26 00:00:00  2020-11-01 00:00:00     15117662
# 5  2020-11-02 00:00:00  2020-11-08 00:00:00     16367093
# 6  2020-11-09 00:00:00  2020-11-15 00:00:00     15894801
# 7  2020-11-16 00:00:00  2020-11-22 00:00:00     16989225
# 8  2020-11-23 00:00:00  2020-11-29 00:00:00     17693441
# 9  2020-11-30 00:00:00  2020-12-06 00:00:00     10576947

# %%
import pandas as pd
import matplotlib.pyplot as plt

df['week_start'] = pd.to_datetime(df['week_start'])
df['week_end'] = pd.to_datetime(df['week_end'])

# Plotting the tweet_count over the tweet_start dates
plt.figure(figsize=(10, 6))

# Plot the tweet_count with tweet_start as the x-axis
plt.plot(df['week_start'], df['tweet_count'], marker='o', linestyle='-', color='b', label='Tweet Count')

# Adding labels and title
plt.xlabel('Tweet Start Date')
plt.ylabel('Tweet Count')
plt.title('Tweet Count Over Time')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Display the legend
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
df["tweet_count"].sum()
# Out:
# 151596087

# %%
df["tweet_count"]=(df["tweet_count"]/151596087)*100
df
# Out:
#             week_start             week_end  tweet_count
# 0  2020-09-28 00:00:00  2020-10-04 00:00:00     8.182042
# 1  2020-10-05 00:00:00  2020-10-11 00:00:00    10.415281
# 2  2020-10-12 00:00:00  2020-10-18 00:00:00    10.785477
# 3  2020-10-19 00:00:00  2020-10-25 00:00:00     9.507992
# 4  2020-10-26 00:00:00  2020-11-01 00:00:00     9.972330
# 5  2020-11-02 00:00:00  2020-11-08 00:00:00    10.796514
# 6  2020-11-09 00:00:00  2020-11-15 00:00:00    10.484968
# 7  2020-11-16 00:00:00  2020-11-22 00:00:00    11.206902
# 8  2020-11-23 00:00:00  2020-11-29 00:00:00    11.671436
# 9  2020-11-30 00:00:00  2020-12-06 00:00:00     6.977058

# %%
df1=pd.read_csv("../largedata/new_range/tweet_with_week_user.csv")
df1
# Out:
#             week_start             week_end  unique_user_count
# 0  2020-09-28 00:00:00  2020-10-04 00:00:00            1012490
# 1  2020-10-05 00:00:00  2020-10-11 00:00:00            1044922
# 2  2020-10-12 00:00:00  2020-10-18 00:00:00            1065514
# 3  2020-10-19 00:00:00  2020-10-25 00:00:00            1050042
# 4  2020-10-26 00:00:00  2020-11-01 00:00:00            1098440
# 5  2020-11-02 00:00:00  2020-11-08 00:00:00            1266369
# 6  2020-11-09 00:00:00  2020-11-15 00:00:00            1165269
# 7  2020-11-16 00:00:00  2020-11-22 00:00:00            1123638
# 8  2020-11-23 00:00:00  2020-11-29 00:00:00            1087066
# 9  2020-11-30 00:00:00  2020-12-06 00:00:00             919504

# %%
df1["unique_user_count"].sum()
# Out:
# 10833254

# %%
df1["unique_user_count"]=(df1["unique_user_count"]/1715006)*100
df1
# Out:
#             week_start             week_end  unique_user_count
# 0  2020-09-28 00:00:00  2020-10-04 00:00:00          59.037111
# 1  2020-10-05 00:00:00  2020-10-11 00:00:00          60.928183
# 2  2020-10-12 00:00:00  2020-10-18 00:00:00          62.128879
# 3  2020-10-19 00:00:00  2020-10-25 00:00:00          61.226725
# 4  2020-10-26 00:00:00  2020-11-01 00:00:00          64.048756
# 5  2020-11-02 00:00:00  2020-11-08 00:00:00          73.840500
# 6  2020-11-09 00:00:00  2020-11-15 00:00:00          67.945477
# 7  2020-11-16 00:00:00  2020-11-22 00:00:00          65.518022
# 8  2020-11-23 00:00:00  2020-11-29 00:00:00          63.385551
# 9  2020-11-30 00:00:00  2020-12-06 00:00:00          53.615206

# %%
df1['year_week'] = df1['week_start'].astype(str) + '/' + df1['week_end'].astype(str)

# %%
df1
# Out:
#             week_start             week_end  unique_user_count  \
# 0  2020-09-28 00:00:00  2020-10-04 00:00:00          59.037111
# 1  2020-10-05 00:00:00  2020-10-11 00:00:00          60.928183
# 2  2020-10-12 00:00:00  2020-10-18 00:00:00          62.128879
# 3  2020-10-19 00:00:00  2020-10-25 00:00:00          61.226725
# 4  2020-10-26 00:00:00  2020-11-01 00:00:00          64.048756
# 5  2020-11-02 00:00:00  2020-11-08 00:00:00          73.840500
# 6  2020-11-09 00:00:00  2020-11-15 00:00:00          67.945477
# 7  2020-11-16 00:00:00  2020-11-22 00:00:00          65.518022
# 8  2020-11-23 00:00:00  2020-11-29 00:00:00          63.385551
# 9  2020-11-30 00:00:00  2020-12-06 00:00:00          53.615206
#
#                                       week  \
# 0  2020-09-28 00:00:00/2020-10-04 00:00:00
# 1  2020-10-05 00:00:00/2020-10-11 00:00:00
# 2  2020-10-12 00:00:00/2020-10-18 00:00:00
# 3  2020-10-19 00:00:00/2020-10-25 00:00:00
# 4  2020-10-26 00:00:00/2020-11-01 00:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_dotwin=unique_authors_df
df_parler=unique_authors_df_parler
df_twitter=df1

df_twitter['year_week'] = df_twitter['week_start'].astype(str) + '/' + df_twitter['week_end'].astype(str)

# Convert 'year_week' to string format (if needed)
df_dotwin['year_week'] = df_dotwin['year_week'].astype(str)
df_parler['year_week'] = df_parler['year_week'].astype(str)

# Align the data points for plotting
all_weeks = sorted(set(df_dotwin['year_week']).union(set(df_parler['year_week']).union(set(df_twitter['year_week']))))

# Fill missing weeks for each platform
df_dotwin = df_dotwin.set_index('year_week').reindex(all_weeks, fill_value=0).reset_index()
df_parler = df_parler.set_index('year_week').reindex(all_weeks, fill_value=0).reset_index()
df_twitter = df_twitter.set_index('year_week').reindex(all_weeks, fill_value=0).reset_index()

# Plotting the data
plt.figure(figsize=(12, 6))

# Plot Dotwin
plt.plot(df_dotwin['year_week'], df_dotwin['unique_authors'], label='Dotwin - Unique Authors', marker='o')

# Plot Parler
plt.plot(df_parler['year_week'], df_parler['creator'], label='Parler - Creators', marker='o')

# Plot Twitter
plt.plot(df_twitter['year_week'], df_twitter['unique_user_count'], label='Twitter - Unique User Count', marker='o')

# Adding labels and title
plt.xlabel('Week')
plt.ylabel('Values')
plt.title('Comparison of Dotwin, Parler, and Twitter Data per Week')

# Adding legend
plt.legend()

# Rotate x labels for better readability and set a tick frequency (show every 4th week)
plt.xticks(ticks=range(0, len(all_weeks), 4), labels=[all_weeks[i] for i in range(0, len(all_weeks), 4)], rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Unique users

# %%
unique_authors_df
# Out:
#                 year_week  unique_authors
# 0   2020-07-27/2020-08-02        0.123970
# 1   2020-08-03/2020-08-09        0.273155
# 2   2020-08-10/2020-08-16        0.262649
# 3   2020-08-17/2020-08-23        0.254244
# 4   2020-08-24/2020-08-30        0.407632
# 5   2020-08-31/2020-09-06        0.395024
# 6   2020-09-07/2020-09-13        0.329887
# 7   2020-09-14/2020-09-20        0.275256
# 8   2020-09-21/2020-09-27        0.294167
# 9   2020-09-28/2020-10-04        0.353001
# 10  2020-10-05/2020-10-11        0.285762
# 11  2020-10-12/2020-10-18        0.247941
# 12  2020-10-19/2020-10-25        0.239536
# 13  2020-10-26/2020-11-01        0.224828
# 14  2020-11-02/2020-11-08        0.376114
# 15  2020-11-09/2020-11-15        0.331989
# 16  2020-11-16/2020-11-22        0.266852
# 17  2020-11-23/2020-11-29        0.714406
# 18  2020-11-30/2020-12-06        0.666078
# 19  2020-12-07/2020-12-13        2.044461
# 20  2020-12-14/2020-12-20       12.020928
# ...

# %%
df1=unique_authors_df
df1
# Out:
#                 year_week  unique_authors
# 15  2020-11-09/2020-11-15  51.235040
# 16  2020-11-16/2020-11-22  30.748418
# 17  2020-11-23/2020-11-29  21.987063
# 18  2020-11-30/2020-12-06  17.326521
# 19  2020-12-07/2020-12-13  15.401532
# 20  2020-12-14/2020-12-20  13.183877
# 21  2020-12-21/2020-12-27  10.846345
# 22  2020-12-28/2021-01-03   8.863211
# 23  2021-01-04/2021-01-10  17.949429
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example DataFrames (replace with actual data)


# Plotting
plt.figure(figsize=(16, 6))

# Plot df1 as a line graph
plt.plot(df1['year_week'].astype(str), df1['unique_authors'], label='Dotwin', linestyle='-', marker='o')

# Plot df2 as a line graph
plt.plot(df2['year_week'].astype(str), df2['unique_authors'], label='Parler', linestyle='-', marker='o')
plt.plot(dp['year_week'].astype(str), dp['unique_authors'], label='Twitter', linestyle='-', marker='o')

# Add labels and title
plt.xlabel('Year Week')
plt.ylabel('Percentage Unique Authors')  # Changed the label to "Percentage"
plt.title('Unique Authors over Time (Line Graph)')

# Add legend
plt.legend()

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %%
dp=pd.read_csv("../largedata/new_range/tweet_with_week_user.csv")
dp
# Out:
#             week_start             week_end  unique_user_count
# 0  2020-09-28 00:00:00  2020-10-04 00:00:00            1012490
# 1  2020-10-05 00:00:00  2020-10-11 00:00:00            1044922
# 2  2020-10-12 00:00:00  2020-10-18 00:00:00            1065514
# 3  2020-10-19 00:00:00  2020-10-25 00:00:00            1050042
# 4  2020-10-26 00:00:00  2020-11-01 00:00:00            1098440
# 5  2020-11-02 00:00:00  2020-11-08 00:00:00            1266369
# 6  2020-11-09 00:00:00  2020-11-15 00:00:00            1165269
# 7  2020-11-16 00:00:00  2020-11-22 00:00:00            1123638
# 8  2020-11-23 00:00:00  2020-11-29 00:00:00            1087066
# 9  2020-11-30 00:00:00  2020-12-06 00:00:00             919504

# %%
dp["unique_user_count"]=(dp["unique_user_count"]/1715006)*100
dp
# Out:
#             week_start             week_end  unique_user_count
# 0  2020-09-28 00:00:00  2020-10-04 00:00:00          59.037111
# 1  2020-10-05 00:00:00  2020-10-11 00:00:00          60.928183
# 2  2020-10-12 00:00:00  2020-10-18 00:00:00          62.128879
# 3  2020-10-19 00:00:00  2020-10-25 00:00:00          61.226725
# 4  2020-10-26 00:00:00  2020-11-01 00:00:00          64.048756
# 5  2020-11-02 00:00:00  2020-11-08 00:00:00          73.840500
# 6  2020-11-09 00:00:00  2020-11-15 00:00:00          67.945477
# 7  2020-11-16 00:00:00  2020-11-22 00:00:00          65.518022
# 8  2020-11-23 00:00:00  2020-11-29 00:00:00          63.385551
# 9  2020-11-30 00:00:00  2020-12-06 00:00:00          53.615206

# %%
dp["unique_user_count"].sum()
# Out:
# 631.6744081361815

# %%
dp['week_start'] = pd.to_datetime(dp['week_start']).dt.date
dp['week_end'] = pd.to_datetime(dp['week_end']).dt.date

# Step 1: Create the year_week column by combining week_start and week_end (as date only)
dp['year_week'] = dp['week_start'].astype(str) + '/' + dp['week_end'].astype(str)

# Step 2: Rename unique_user_count to unique_authors
dp = dp.rename(columns={'unique_user_count': 'unique_authors'})

# Step 3: Drop the original week_start and week_end columns
dp = dp[['year_week', 'unique_authors']]
dp
# Out:
#                year_week  unique_authors
# 0  2020-09-28/2020-10-04       59.037111
# 1  2020-10-05/2020-10-11       60.928183
# 2  2020-10-12/2020-10-18       62.128879
# 3  2020-10-19/2020-10-25       61.226725
# 4  2020-10-26/2020-11-01       64.048756
# 5  2020-11-02/2020-11-08       73.840500
# 6  2020-11-09/2020-11-15       67.945477
# 7  2020-11-16/2020-11-22       65.518022
# 8  2020-11-23/2020-11-29       63.385551
# 9  2020-11-30/2020-12-06       53.615206

# %%
print(dp)
# Out:
#                                  year_week  unique_authors
# 0  2020-09-28 00:00:00/2020-10-04 00:00:00       59.037111
# 1  2020-10-05 00:00:00/2020-10-11 00:00:00       60.928183
# 2  2020-10-12 00:00:00/2020-10-18 00:00:00       62.128879
# 3  2020-10-19 00:00:00/2020-10-25 00:00:00       61.226725
# 4  2020-10-26 00:00:00/2020-11-01 00:00:00       64.048756
# 5  2020-11-02 00:00:00/2020-11-08 00:00:00       73.840500
# 6  2020-11-09 00:00:00/2020-11-15 00:00:00       67.945477
# 7  2020-11-16 00:00:00/2020-11-22 00:00:00       65.518022
# 8  2020-11-23 00:00:00/2020-11-29 00:00:00       63.385551
# 9  2020-11-30 00:00:00/2020-12-06 00:00:00       53.615206

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example DataFrames (replace with actual data)
# Assuming df1, df2, and dp are your dataframes

# Ensure 'year_week' is in the same format (assuming it's a string)
df1['year_week'] = df1['year_week'].astype(str)
df2['year_week'] = df2['year_week'].astype(str)
dp['year_week'] = dp['year_week'].astype(str)

# Extend df2 and dp to match the range of weeks in df1
all_weeks = df1['year_week']

# Reindex df2 and dp to match the weeks in df1
df2_extended = df2.set_index('year_week').reindex(all_weeks).reset_index()
dp_extended = dp.set_index('year_week').reindex(all_weeks).reset_index()

# Fill missing values with 0
df2_extended['unique_authors'] = df2_extended['unique_authors'].fillna(0)
dp_extended['unique_authors'] = dp_extended['unique_authors'].fillna(0)

# Plotting
plt.figure(figsize=(16, 6))

# Plot df1 as a line graph
plt.plot(df1['year_week'], df1['unique_authors'], label='Dotwin', linestyle='-', marker='o')

# Plot df2 as a line graph
plt.plot(df2_extended['year_week'], df2_extended['unique_authors'], label='Parler', linestyle='-', marker='o')

# Plot dp as a line graph
plt.plot(dp_extended['year_week'], dp_extended['unique_authors'], label='Twitter', linestyle='-', marker='o')

# Add labels and title
plt.xlabel('Year Week')
plt.ylabel('Percentage Unique Authors')
plt.title('Unique Authors over Time (Line Graph)')

# Add legend
plt.legend()

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## extended part different color

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure 'year_week' is in the same format (assuming it's a string)
df1['year_week'] = df1['year_week'].astype(str)
df2['year_week'] = df2['year_week'].astype(str)
dp['year_week'] = dp['year_week'].astype(str)

# Extend dp to match the range of weeks in df1
all_weeks = df1['year_week']

# Reindex dp to match the weeks in df1
dp_extended = dp.set_index('year_week').reindex(all_weeks).reset_index()

# Fill missing values with 0
dp_extended['unique_authors'] = dp_extended['unique_authors'].fillna(0)

# Identify the original and extended parts for Twitter
dp_original_weeks = dp['year_week'].unique()

# Plotting
plt.figure(figsize=(16, 6))

# Plot df1 (Dotwin) as a line graph
plt.plot(df1['year_week'], df1['unique_authors'], label='Dotwin', linestyle='-', marker='o', color='blue')

# Plot df2 (Parler) as a line graph
plt.plot(df2['year_week'], df2['unique_authors'], label='Parler', linestyle='-', marker='o', color='green')

# Plot the Twitter data in two segments: red for original, grey for extended
plt.plot(dp_extended['year_week'], dp_extended['unique_authors'], linestyle='-', marker='o', color='red')

# Overlay the grey part for the extended data (but maintain continuity of the line)
plt.plot(dp_extended[~dp_extended['year_week'].isin(dp_original_weeks)]['year_week'], 
         dp_extended[~dp_extended['year_week'].isin(dp_original_weeks)]['unique_authors'], 
         linestyle='-', marker='o', color='grey')

# Add labels and title
plt.xlabel('Year Week')
plt.ylabel('Percentage Unique Authors')
plt.title('Unique Authors over Time (Line Graph)')

# Add legend
plt.legend(['Dotwin', 'Parler', 'Twitter'])

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## final extended

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure 'year_week' is in the same format (assuming it's a string)
df1['year_week'] = df1['year_week'].astype(str)
df2['year_week'] = df2['year_week'].astype(str)
dp['year_week'] = dp['year_week'].astype(str)

# Extend dp to match the range of weeks in df1
all_weeks = df1['year_week']

# Reindex dp to match the weeks in df1
dp_extended = dp.set_index('year_week').reindex(all_weeks).reset_index()

# Fill missing values with 0
dp_extended['unique_authors'] = dp_extended['unique_authors'].fillna(0)

# Identify the original and extended parts for Twitter
dp_original_weeks = dp['year_week'].unique()

# Plotting
plt.figure(figsize=(16, 6))

# Plot df1 (Dotwin) as a line graph
plt.plot(df1['year_week'], df1['unique_authors'], label='Dotwin', linestyle='-', marker='o', color='blue')

# Plot df2 (Parler) as a line graph
plt.plot(df2['year_week'], df2['unique_authors'], label='Parler', linestyle='-', marker='o', color='green')

# First plot the Twitter data as grey for both original and extended parts
plt.plot(dp_extended['year_week'], dp_extended['unique_authors'], linestyle='-', marker='o', color='black')

# Then, overlay the original Twitter data in red, maintaining the continuity of the line
plt.plot(dp_extended[dp_extended['year_week'].isin(dp_original_weeks)]['year_week'], 
         dp_extended[dp_extended['year_week'].isin(dp_original_weeks)]['unique_authors'], 
         linestyle='-', marker='o', color='orange')

# Add labels and title
plt.xlabel('Year Week')
plt.ylabel('Percentage Unique Authors')
plt.title('Unique Authors over Time (Line Graph)')

# Add legend
plt.legend(['Dotwin', 'Parler', 'Twitter (Extended)', 'Twitter (Original)'])

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure 'year_week' is in the same format (assuming it's a string)
df1['year_week'] = df1['year_week'].astype(str)
df2['year_week'] = df2['year_week'].astype(str)
dp['year_week'] = dp['year_week'].astype(str)

# Extend dp to match the range of weeks in df1
all_weeks = df1['year_week']

# Reindex dp to match the weeks in df1
dp_extended = dp.set_index('year_week').reindex(all_weeks).reset_index()

# Fill missing values with 0
dp_extended['unique_authors'] = dp_extended['unique_authors'].fillna(0)

# Identify the original and extended parts for Twitter
dp_original_weeks = dp['year_week'].unique()

# Define Wong color-blind friendly palette
wong_palette = ['#000000', '#E69F00', '#56B4E9', '#009E73', '#F0E442', '#0072B2', '#D55E00', '#CC79A7']

# Plotting
plt.figure(figsize=(16, 6))

# Plot df1 (Dotwin) as a line graph
plt.plot(df1['year_week'], df1['unique_authors'], label='Dotwin', linestyle='-', marker='o', color=wong_palette[5])  # Blue

# Plot df2 (Parler) as a line graph
plt.plot(df2['year_week'], df2['unique_authors'], label='Parler', linestyle='-', marker='o', color=wong_palette[6])  # Bluish Green

# First plot the Twitter data as grey for both original and extended parts
plt.plot(dp_extended['year_week'], dp_extended['unique_authors'], linestyle='-', marker='o', color=wong_palette[0])  # Black

# Then, overlay the original Twitter data in orange, maintaining the continuity of the line
plt.plot(dp_extended[dp_extended['year_week'].isin(dp_original_weeks)]['year_week'], 
         dp_extended[dp_extended['year_week'].isin(dp_original_weeks)]['unique_authors'], 
         linestyle='-', marker='o', color=wong_palette[4])  # Orange

# Add labels and title
plt.xlabel('Year Week')
plt.ylabel('Percentage Unique Authors')
plt.title('Unique Authors over Time (Line Graph)')

# Add legend
plt.legend(['Dotwin', 'Parler', 'Twitter (Extended)', 'Twitter (Original)'])

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %%
# !pip install plotly
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 32.6 MB/s eta 0:00:0000:0100:01
# ...

# %%
df1
# Out:
#                 year_week  unique_authors
# 0   2020-07-27/2020-08-02        0.123970
# 1   2020-08-03/2020-08-09        0.273155
# 2   2020-08-10/2020-08-16        0.262649
# 3   2020-08-17/2020-08-23        0.254244
# 4   2020-08-24/2020-08-30        0.407632
# 5   2020-08-31/2020-09-06        0.395024
# 6   2020-09-07/2020-09-13        0.329887
# 7   2020-09-14/2020-09-20        0.275256
# 8   2020-09-21/2020-09-27        0.294167
# 9   2020-09-28/2020-10-04        0.353001
# 10  2020-10-05/2020-10-11        0.285762
# Add labels and title
plt.xlabel('Year Week')
plt.ylabel('Percentage Unique Authors')  # Changed the label to "Percentage"
plt.title('Unique Authors over Time (Line Graph)')

# Add legend
plt.legend()

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)
plt.grid(True)
# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Unique users poster

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example DataFrames (replace with actual data)
# df1, df2, and dp should be defined with columns 'year_week' and 'unique_authors'

# Define a colorblind-friendly palette
colors = ['#E69F00', '#56B4E9', '#009E73']

# Plotting
plt.figure(figsize=(16, 6))

# Plot df1 as a line graph
plt.plot(df1['year_week'].astype(str), df1['unique_authors'], label='Dotwin', linestyle='-', marker='o', color=colors[0])

# Plot df2 as a line graph
plt.plot(df2['year_week'].astype(str), df2['unique_authors'], label='Parler', linestyle='-', marker='o', color=colors[1])

# Plot dp as a line graph
plt.plot(dp['year_week'].astype(str), dp['unique_authors'], label='Twitter', linestyle='-', marker='o', color=colors[2])

# Add labels and title
plt.xlabel('Year Week')
plt.ylabel('Percentage Unique Authors')  # Changed the label to "Percentage"
# plt.title('Unique Authors over Time (Line Graph)')

# Add legend
plt.legend()

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)
plt.grid(True)

# Remove top and right spines
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Unique posts over time

# %% [markdown]
# ## twitter

# %%
import pandas as pd
df_twitter=pd.read_csv("../largedata/new_range/twitter/post_tweets_week.csv")
df_twitter
# Out:
#             start_week             end_week  tweet_count
# 0  2020-09-28 00:00:00  2020-10-04 00:00:00       551922
# 1  2020-10-05 00:00:00  2020-10-11 00:00:00       615915
# 2  2020-10-12 00:00:00  2020-10-18 00:00:00       595287
# 3  2020-10-19 00:00:00  2020-10-25 00:00:00       600185
# 4  2020-10-26 00:00:00  2020-11-01 00:00:00       652838
# 5  2020-11-02 00:00:00  2020-11-08 00:00:00       706268
# 6  2020-11-09 00:00:00  2020-11-15 00:00:00       613098
# 7  2020-11-16 00:00:00  2020-11-22 00:00:00       688389
# 8  2020-11-23 00:00:00  2020-11-29 00:00:00       733923
# 9  2020-11-30 00:00:00  2020-12-06 00:00:00       453746

# %%
dp=df_twitter
dp
# Out:
#             start_week             end_week  tweet_count
# 0  2020-09-28 00:00:00  2020-10-04 00:00:00       551922
# 1  2020-10-05 00:00:00  2020-10-11 00:00:00       615915
# 2  2020-10-12 00:00:00  2020-10-18 00:00:00       595287
# 3  2020-10-19 00:00:00  2020-10-25 00:00:00       600185
# 4  2020-10-26 00:00:00  2020-11-01 00:00:00       652838
# 5  2020-11-02 00:00:00  2020-11-08 00:00:00       706268
# 6  2020-11-09 00:00:00  2020-11-15 00:00:00       613098
# 7  2020-11-16 00:00:00  2020-11-22 00:00:00       688389
# 8  2020-11-23 00:00:00  2020-11-29 00:00:00       733923
# 9  2020-11-30 00:00:00  2020-12-06 00:00:00       453746

# %%
dp['start_week'] = pd.to_datetime(dp['start_week']).dt.date
dp['end_week'] = pd.to_datetime(dp['end_week']).dt.date

# Step 1: Create the year_week column by combining week_start and week_end (as date only)
dp['year_week'] = dp['start_week'].astype(str) + '/' + dp['end_week'].astype(str)

# Step 2: Rename unique_user_count to unique_authors
dp = dp.rename(columns={'tweet_count': 'count'})

# Step 3: Drop the original week_start and week_end columns
dp = dp[['year_week', 'count']]
dp
# Out:
#                year_week   count
# 0  2020-09-28/2020-10-04  551922
# 1  2020-10-05/2020-10-11  615915
# 2  2020-10-12/2020-10-18  595287
# 3  2020-10-19/2020-10-25  600185
# 4  2020-10-26/2020-11-01  652838
# 5  2020-11-02/2020-11-08  706268
# 6  2020-11-09/2020-11-15  613098
# 7  2020-11-16/2020-11-22  688389
# 8  2020-11-23/2020-11-29  733923
# 9  2020-11-30/2020-12-06  453746

# %%
dp["count"].sum()
# Out:
# 6211571

# %%
dp["count"]=dp["count"]/6211571*100

# %%
dp
# Out:
#                year_week      count
# 0  2020-09-28/2020-10-04   8.885385
# 1  2020-10-05/2020-10-11   9.915608
# 2  2020-10-12/2020-10-18   9.583518
# 3  2020-10-19/2020-10-25   9.662370
# 4  2020-10-26/2020-11-01  10.510030
# 5  2020-11-02/2020-11-08  11.370199
# 6  2020-11-09/2020-11-15   9.870257
# 7  2020-11-16/2020-11-22  11.082365
# 8  2020-11-23/2020-11-29  11.815417
# 9  2020-11-30/2020-12-06   7.304851

# %%
dp["count"].sum()
# Out:
# 100.0

# %%
dp
# Out:
#                year_week      count
# 0  2020-09-28/2020-10-04   8.885385
# 1  2020-10-05/2020-10-11   9.915608
# 2  2020-10-12/2020-10-18   9.583518
# 3  2020-10-19/2020-10-25   9.662370
# 4  2020-10-26/2020-11-01  10.510030
# 5  2020-11-02/2020-11-08  11.370199
# 6  2020-11-09/2020-11-15   9.870257
# 7  2020-11-16/2020-11-22  11.082365
# 8  2020-11-23/2020-11-29  11.815417
# 9  2020-11-30/2020-12-06   7.304851

# %% [markdown]
# ## dotwin

# %%
po=pd.read_pickle("../largedata/dotwin/dotwin_posts.pkl")
po
# Out:
#                   site         pid    data_id           timestamp  votes  \
# 0       kotakuinaction    GIEZWkV7   401761.0 2020-06-29 22:25:27  636.0
# 1       kotakuinaction    GIEaf8gj   402711.0 2020-06-30 01:16:57  219.0
# 2       kotakuinaction    GIEaf8oz   402731.0 2020-06-30 01:20:47  349.0
# 3       kotakuinaction    GIEaf8p2   402734.0 2020-06-30 01:21:01  572.0
# 4       kotakuinaction    GIEaf8xF   402751.0 2020-06-30 01:24:37  444.0
# ...                ...         ...        ...                 ...    ...
# 227173       thedonald  12hRCKGD22  2028242.0 2021-02-09 15:00:28    3.0
# 227174  greatawakening  12hRCKGD23  2028243.0 2021-02-09 15:00:30    2.0
# 227175       thedonald  12hRCKGD24  2028244.0 2021-02-09 15:00:50    2.0
# 227176       thedonald  12hRCKGD25  2028245.0 2021-02-09 15:01:06    1.0
# 227177  greatawakening  12hRCKGD26  2028246.0 2021-02-09 15:02:27    1.0
#
#         upvotes  downvotes        author  \
# 0         646.0       10.0    HandofBane
# ...

# %%
po= po[po['timestamp'] >= '2020-08-01']
po['year_week'] = po['timestamp'].dt.to_period('W')
po
# Out:
# /tmp/ipykernel_573838/1698374591.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po['year_week'] = po['timestamp'].dt.to_period('W')
#                   site         pid    data_id           timestamp  votes  \
# 542      weekendgunnit    GbtUTN26   541386.0 2020-08-01 14:02:07   93.0
# 543      weekendgunnit    GbtUTurZ   541541.0 2020-08-01 14:48:34   53.0
# 544      weekendgunnit    GbtUUT1n   541753.0 2020-08-01 15:43:10   57.0
# 545      weekendgunnit    GbtVd8nT   542883.0 2020-08-01 20:09:04   77.0
# 546      weekendgunnit    GbtWlnxx   543921.0 2020-08-02 01:07:04   40.0
# ...                ...         ...        ...                 ...    ...
# 227173       thedonald  12hRCKGD22  2028242.0 2021-02-09 15:00:28    3.0
# ...

# %%
po=po[["author","year_week"]]
po
# Out:
#                  author              year_week
# 542      Rawnold_Reagan  2020-07-27/2020-08-02
# 543     GarudaDarkblack  2020-07-27/2020-08-02
# 544           Sunsetmal  2020-07-27/2020-08-02
# 545                arma  2020-07-27/2020-08-02
# 546              Gewehr  2020-07-27/2020-08-02
# ...                 ...                    ...
# 227173        KuzoKevin  2021-02-08/2021-02-14
# 227174         undine53  2021-02-08/2021-02-14
# 227175          Danleif  2021-02-08/2021-02-14
# 227176          Awshit1  2021-02-08/2021-02-14
# 227177          MikeWho  2021-02-08/2021-02-14
# 12  2020-10-19/2020-10-25   0.037946
# 13  2020-10-26/2020-11-01   0.029563
# 14  2020-11-02/2020-11-08   0.037064
# 15  2020-11-09/2020-11-15   0.030004
# 16  2020-11-16/2020-11-22   0.020738
# 17  2020-11-23/2020-11-29   0.090895
# 18  2020-11-30/2020-12-06   0.076334
# 19  2020-12-07/2020-12-13   0.103249
# 20  2020-12-14/2020-12-20   0.137666
# 21  2020-12-21/2020-12-27   0.166787
# 22  2020-12-28/2021-01-03   0.558605
# 23  2021-01-04/2021-01-10   7.887979
# ...

# %%
unique_posts_week ["count"].sum()
# Out:
# 99.99999999999999

# %% [markdown]
# ## parler

# %%
df_parler=pd.read_csv("../largedata/new_range/parler_huge.csv",usecols=['datatype', 'year_week'])
df_parler
# Out:
#           datatype              year_week
# 0            posts  2020-11-30/2020-12-06
# 1            posts  2020-11-23/2020-11-29
# 2            posts  2020-11-02/2020-11-08
# 3            posts  2020-12-14/2020-12-20
# 4            posts  2020-10-26/2020-11-01
# ...            ...                    ...
# 138620026    posts  2020-08-31/2020-09-06
# 138620027    posts  2020-12-07/2020-12-13
# 138620028    posts  2020-08-24/2020-08-30
# 138620029    posts  2020-12-28/2021-01-03
# 138620030    posts  2020-11-02/2020-11-08
#
# [138620031 rows x 2 columns]

# %%
filtered_df = df_parler[df_parler['datatype'] == 'posts']
filtered_df
# Out:
#           datatype              year_week
# 0            posts  2020-11-30/2020-12-06
# 1            posts  2020-11-23/2020-11-29
# 2            posts  2020-11-02/2020-11-08
# 3            posts  2020-12-14/2020-12-20
# 4            posts  2020-10-26/2020-11-01
# ...            ...                    ...
# 138620026    posts  2020-08-31/2020-09-06
# 138620027    posts  2020-12-07/2020-12-13
# 138620028    posts  2020-08-24/2020-08-30
# 138620029    posts  2020-12-28/2021-01-03
# 138620030    posts  2020-11-02/2020-11-08
#
# [72891865 rows x 2 columns]

# %%
print("t")
# Out:
# t

# %%
unique_posts_week_parler = filtered_df.groupby('year_week').size().reset_index(name='count')
unique_posts_week_parler
# Out:
#                 year_week    count
# 0   2020-07-27/2020-08-02   516752
# 1   2020-08-03/2020-08-09  1638504
# 2   2020-08-10/2020-08-16  1629109
# 3   2020-08-17/2020-08-23  1705399
# 4   2020-08-24/2020-08-30  1680744
# 5   2020-08-31/2020-09-06  1729628
# 6   2020-09-07/2020-09-13  1582373
# 7   2020-09-14/2020-09-20  1522238
# 8   2020-09-21/2020-09-27  1545692
# 9   2020-09-28/2020-10-04  1599102
# 10  2020-10-05/2020-10-11  1631248
# 11  2020-10-12/2020-10-18  1934656
# 12  2020-10-19/2020-10-25  2036739
# 13  2020-10-26/2020-11-01  2180882
# 14  2020-11-02/2020-11-08  3823416
# 15  2020-11-09/2020-11-15  8481357
# 16  2020-11-16/2020-11-22  6975302
# 17  2020-11-23/2020-11-29  6247350
# 18  2020-11-30/2020-12-06  5380331
# 19  2020-12-07/2020-12-13  5099823
# 20  2020-12-14/2020-12-20  4627176
# 21  2020-12-21/2020-12-27  3407360
# 22  2020-12-28/2021-01-03  2397801
# 23  2021-01-04/2021-01-10  3497289
# 24  2021-01-11/2021-01-17    21594

# %%
unique_posts_week_parler["count"].sum()
# Out:
# 72891865

# %%
unique_posts_week_parler["count"]=unique_posts_week_parler["count"]/72891865*100
unique_posts_week_parler
# Out:
#                 year_week      count
# 0   2020-07-27/2020-08-02   0
# 10  2020-10-05/2020-10-11   2.237901
# 11  2020-10-12/2020-10-18   2.654145
# 12  2020-10-19/2020-10-25   2.794192
# 13  2020-10-26/2020-11-01   2.991942
# 14  2020-11-02/2020-11-08   5.245326
# 15  2020-11-09/2020-11-15  11.635533
# 16  2020-11-16/2020-11-22   9.569383
# 17  2020-11-23/2020-11-29   8.570710
# 18  2020-11-30/2020-12-06   7.381250
# 19  2020-12-07/2020-12-13   6.996423
# 20  2020-12-14/2020-12-20   6.348001
# 21  2020-12-21/2020-12-27   4.674541
# 22  2020-12-28/2021-01-03   3.289532
# 23  2021-01-04/2021-01-10   4.797914
# ...

# %%
df1
# Out:
#                 year_week      count
# 0   2020-07-27/2020-08-02   0.004854
# 1   2020-08-03/2020-08-09   0.016767
# 2   2020-08-10/2020-08-16   0.018091
# 3   2020-08-17/2020-08-23   0.010590
# 4   2020-08-24/2020-08-30   0.040152
# 5   2020-08-31/2020-09-06   0.066185
# 6   2020-09-07/2020-09-13   0.053390
# 7   2020-09-14/2020-09-20   0.041035
# 8   2020-09-21/2020-09-27   0.050301
# 9   2020-09-28/2020-10-04   0.052507
# 10  2020-10-05/2020-10-11   0.040152
# 11  2020-10-12/2020-10-18   0.038829
# 12  2020-10-19/2020-10-25   0.037946
# 13  2020-10-26/2020-11-01   0.029563
# 14  2020-11-02/2020-11-08   0.037064
# 15  2020-11-09/2020-11-15   0.030004
# 16  2020-11-16/2020-11-22   0.020738
# 17  2020-11-23/2020-11-29   0.090895
# 18  2020-11-30/2020-12-06   0.076334
# 19  2020-12-07/2020-12-13   0.103249
# 20  2020-12-14/2020-12-20   0.137666
# 21  2020-12-21/2020-12-27   0.166787
# 22  2020-12-28/2021-01-03   0.558605
# 23  2021-01-04/2021-01-10   7.887979
# ...

# %%
dp
# Out:
#                year_week      count
# 0  2020-09-28/2020-10-04   8.885385
# 1  2020-10-05/2020-10-11   9.915608
# 2  2020-10-12/2020-10-18   9.583518
# 3  2020-10-19/2020-10-25   9.662370
# 4  2020-10-26/2020-11-01  10.510030
# 5  2020-11-02/2020-11-08  11.370199
# 6  2020-11-09/2020-11-15   9.870257
# 7  2020-11-16/2020-11-22  11.082365
# 8  2020-11-23/2020-11-29  11.815417
# 9  2020-11-30/2020-12-06   7.304851

# %%
df2.to_csv("../largedata/new_range/week_analysis_parler/post_parler.csv",index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure 'year_week' is in the same format (assuming it's a string)
df1['year_week'] = df1['year_week'].astype(str)
df2['year_week'] = df2['year_week'].astype(str)
dp['year_week'] = dp['year_week'].astype(str)

# Extend dp to match the range of weeks in df1
all_weeks = df1['year_week']

# Reindex dp to match the weeks in df1
dp_extended = dp.set_index('year_week').reindex(all_weeks).reset_index()

# Fill missing values with 0
dp_extended['count'] = dp_extended['count'].fillna(0)

# Identify the original and extended parts for Twitter
dp_original_weeks = dp['year_week'].unique()

# Plotting
plt.figure(figsize=(16, 6))

# Plot df1 (Dotwin) as a line graph
plt.plot(df1['year_week'], df1['count'], label='Dotwin', linestyle='-', marker='o', color='blue')

# Plot df2 (Parler) as a line graph
plt.plot(df2['year_week'], df2['count'], label='Parler', linestyle='-', marker='o', color='green')

# First plot the Twitter data as grey for both original and extended parts
plt.plot(dp_extended['year_week'], dp_extended['count'], linestyle='-', marker='o', color='black')

# Then, overlay the original Twitter data in red, maintaining the continuity of the line
plt.plot(dp_extended[dp_extended['year_week'].isin(dp_original_weeks)]['year_week'], 
         dp_extended[dp_extended['year_week'].isin(dp_original_weeks)]['count'], 
         linestyle='-', marker='o', color='orange')

# Add labels and title
plt.xlabel('Year Week')
plt.ylabel('Percentage of posts')
plt.title('Posts over Time (Line Graph)')

# Add legend
plt.legend(['Dotwin', 'Parler', 'Twitter (Extended)', 'Twitter (Original)'])

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)
plt.grid(True)
# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example DataFrames (replace with actual data)


# Plotting
plt.figure(figsize=(16, 6))

# Plot df1 as a line graph
plt.plot(df1['year_week'].astype(str), df1['count'], label='Dotwin', linestyle='-', marker='o')

# Plot df2 as a line graph
plt.plot(df2['year_week'].astype(str), df2['count'], label='Parler', linestyle='-', marker='o')
plt.plot(dp['year_week'].astype(str), dp['count'], label='Twitter', linestyle='-', marker='o')

# Add labels and title
plt.xlabel('Year Week')
plt.ylabel('Percentage of posts')  # Changed the label to "Percentage"
plt.title('Posts over Time (Line Graph)')

# Add legend
plt.legend()

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)
plt.grid(True)
# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Comments over time

# %% [markdown]
# ## dotwin

# %%
co=pd.read_pickle("../largedata/dotwin/dotwin_comments.pkl")
co
# Out:
#                    site         pid                      permalink  \
# 0        kotakuinaction    GIEZWkV7     /p/GIEZWkV7/x/c/12jw8CGTdC
# 1        kotakuinaction    GIEZWkV7     /p/GIEZWkV7/x/c/12jw8CGTxs
# 2        kotakuinaction    GIEZWkV7     /p/GIEZWkV7/x/c/12jw8CGkoX
# 3        kotakuinaction    GIEZWkV7     /p/GIEZWkV7/x/c/12jw8CGksi
# 4        kotakuinaction    GIEZWkV7     /p/GIEZWkV7/x/c/12jw8CGl0s
# ...                 ...         ...                            ...
# 1601646       thedonald  12hRCKGD22  /p/12hRCKGD22/x/c/4Dx42GGn7fk
# 1601647       thedonald  12hRCKFwJf  /p/12hRCKFwJf/x/c/4Dx42GGn7o1
# 1601648       thedonald  12hRCKFwJf  /p/12hRCKFwJf/x/c/4Dx42GGn7sE
# 1601649       thedonald  12hRCJ9jee  /p/12hRCJ9jee/x/c/4Dx42GGn7sH
# 1601650       thedonald  12hRCKFwJf  /p/12hRCKFwJf/x/c/4Dx42GGn80O
#
#                   timestamp  upvotes  downvotes               author  \
# 0       2020-06-29 22:38:43       17          3       TheWhiteFalcon
# ...

# %%
co= co[co['timestamp'] >= '2020-08-01']
co['year_week'] = co['timestamp'].dt.to_period('W')
co
# Out:
# /tmp/ipykernel_573838/1648338203.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co['year_week'] = co['timestamp'].dt.to_period('W')
#                   site         pid                      permalink  \
# 4986     weekendgunnit    GbotTGtV     /p/GbotTGtV/x/c/142BJfl8q5
# 4987     weekendgunnit    GborDaRt     /p/GborDaRt/x/c/142BJflPxH
# 4988     weekendgunnit    GbotTovQ     /p/GbotTovQ/x/c/142BJgtX1k
# 4989     weekendgunnit    GbomgYGR     /p/GbomgYGR/x/c/142BJgtoD1
# 4990     weekendgunnit    GbkBi6cN     /p/GbkBi6cN/x/c/142BJhzj5Z
# ...                ...         ...                            ...
# 1601646      thedonald  12hRCKGD22  /p/12hRCKGD22/x/c/4Dx42GGn7fk
# ...

# %%
co=co[["author","year_week"]]
co
# Out:
#                       author              year_week
# 4986                BigIgloo  2020-07-27/2020-08-02
# 4987                  Tubesy  2020-07-27/2020-08-02
# 4988              HonkNJhonk  2020-07-27/2020-08-02
# 4989                  migger  2020-07-27/2020-08-02
# 4990                  migger  2020-07-27/2020-08-02
# ...                      ...                    ...
# 1601646            KuzoKevin  2021-02-08/2021-02-14
# 1601647  Boilingsnowflakes4u  2021-02-08/2021-02-14
# 1601648           MythArcana  2021-02-08/2021-02-14
# 15  2020-11-09/2020-11-15  14.938465
# 16  2020-11-16/2020-11-22  11.055191
# 17  2020-11-23/2020-11-29   8.144044
# 18  2020-11-30/2020-12-06   6.225086
# 19  2020-12-07/2020-12-13   6.502378
# 20  2020-12-14/2020-12-20   5.911974
# 21  2020-12-21/2020-12-27   4.368345
# 22  2020-12-28/2021-01-03   3.708346
# 23  2021-01-04/2021-01-10   5.649175
# ...

# %%
df2.to_csv("../largedata/new_range/week_analysis_parler/comment_parler.csv",index=False)

# %% [markdown]
# ## twitter

# %%
d1=pd.read_csv("../largedata/new_range/twitter/quote_tweets_week.csv")
d1
# Out:
#             start_week             end_week  tweet_count
# 0  2020-09-28 00:00:00  2020-10-04 00:00:00       701798
# 1  2020-10-05 00:00:00  2020-10-11 00:00:00       874256
# 2  2020-10-12 00:00:00  2020-10-18 00:00:00       889348
# 3  2020-10-19 00:00:00  2020-10-25 00:00:00      1130476
# 4  2020-10-26 00:00:00  2020-11-01 00:00:00      1356612
# 5  2020-11-02 00:00:00  2020-11-08 00:00:00      1432696
# 6  2020-11-09 00:00:00  2020-11-15 00:00:00      1351076
# 7  2020-11-16 00:00:00  2020-11-22 00:00:00      1434309
# 8  2020-11-23 00:00:00  2020-11-29 00:00:00      1522526
# 9  2020-11-30 00:00:00  2020-12-06 00:00:00       889534

# %%
d1["tweet_count"].sum()
# Out:
# 11582631

# %%
d2=pd.read_csv("../largedata/new_range/twitter/reply_tweets_week.csv")
d2
# Out:
#             start_week             end_week  tweet_count
# 0  2020-09-28 00:00:00  2020-10-04 00:00:00       965590
# 1  2020-10-05 00:00:00  2020-10-11 00:00:00      1237022
# 2  2020-10-12 00:00:00  2020-10-18 00:00:00      1291646
# 3  2020-10-19 00:00:00  2020-10-25 00:00:00      1163251
# 4  2020-10-26 00:00:00  2020-11-01 00:00:00      1377324
# 5  2020-11-02 00:00:00  2020-11-08 00:00:00      1434156
# 6  2020-11-09 00:00:00  2020-11-15 00:00:00      1442154
# 7  2020-11-16 00:00:00  2020-11-22 00:00:00      1599712
# 8  2020-11-23 00:00:00  2020-11-29 00:00:00      1705016
# 9  2020-11-30 00:00:00  2020-12-06 00:00:00       966107

# %%
d2["tweet_count"].sum()
# Out:
# 13181978

# %%
# Merge the two DataFrames on 'col1' and 'col2'
merged_df = pd.merge(d1, d2, on=['start_week', 'end_week'], suffixes=('_d1', '_d2'))

# Sum the 'value' columns from both DataFrames
merged_df['tweet_count_sum'] = merged_df['tweet_count_d1'] + merged_df['tweet_count_d2']

# Drop the original value columns if needed
merged_df = merged_df.drop(columns=['tweet_count_d1', 'tweet_count_d2'])

# Display the result
merged_df
# Out:
#             start_week             end_week  tweet_count_sum
# 0  2020-09-28 00:00:00  2020-10-04 00:00:00          1667388
# 1  2020-10-05 00:00:00  2020-10-11 00:00:00          2111278
# 2  2020-10-12 00:00:00  2020-10-18 00:00:00          2180994
# 3  2020-10-19 00:00:00  2020-10-25 00:00:00          2293727
# 4  2020-10-26 00:00:00  2020-11-01 00:00:00          2733936
# 5  2020-11-02 00:00:00  2020-11-08 00:00:00          2866852
# 6  2020-11-09 00:00:00  2020-11-15 00:00:00          2793230
# 7  2020-11-16 00:00:00  2020-11-22 00:00:00          3034021
# 8  2020-11-23 00:00:00  2020-11-29 00:00:00          3227542
# 9  2020-11-30 00:00:00  2020-12-06 00:00:00          1855641

# %%
print("k")
# Out:
# k

# %%
dp=merged_df
dp
# Out:
#             start_week             end_week  tweet_count_sum
# 0  2020-09-28 00:00:00  2020-10-04 00:00:00          1667388
# 1  2020-10-05 00:00:00  2020-10-11 00:00:00          2111278
# 2  2020-10-12 00:00:00  2020-10-18 00:00:00          2180994
# 3  2020-10-19 00:00:00  2020-10-25 00:00:00          2293727
# 4  2020-10-26 00:00:00  2020-11-01 00:00:00          2733936
# 5  2020-11-02 00:00:00  2020-11-08 00:00:00          2866852
# 6  2020-11-09 00:00:00  2020-11-15 00:00:00          2793230
# 7  2020-11-16 00:00:00  2020-11-22 00:00:00          3034021
# 8  2020-11-23 00:00:00  2020-11-29 00:00:00          3227542
# 9  2020-11-30 00:00:00  2020-12-06 00:00:00          1855641

# %%
dp['start_week'] = pd.to_datetime(dp['start_week']).dt.date
dp['end_week'] = pd.to_datetime(dp['end_week']).dt.date

# Step 1: Create the year_week column by combining week_start and week_end (as date only)
dp['year_week'] = dp['start_week'].astype(str) + '/' + dp['end_week'].astype(str)

# Step 2: Rename unique_user_count to unique_authors
dp = dp.rename(columns={'tweet_count_sum': 'count'})

# Step 3: Drop the original week_start and week_end columns
dp = dp[['year_week', 'count']]
dp
# Out:
#                year_week    count
# 0  2020-09-28/2020-10-04  1667388
# 1  2020-10-05/2020-10-11  2111278
# 2  2020-10-12/2020-10-18  2180994
# 3  2020-10-19/2020-10-25  2293727
# 4  2020-10-26/2020-11-01  2733936
# 5  2020-11-02/2020-11-08  2866852
# 6  2020-11-09/2020-11-15  2793230
# 7  2020-11-16/2020-11-22  3034021
# 8  2020-11-23/2020-11-29  3227542
# 9  2020-11-30/2020-12-06  1855641

# %%
dp["count"].sum()
# Out:
# 24764609

# %%
dp["count"]=dp["count"]/24764609*100
dp
# Out:
#                year_week      count
# 0  2020-09-28/2020-10-04   6.732947
# 1  2020-10-05/2020-10-11   8.525384
# 2  2020-10-12/2020-10-18   8.806899
# 3  2020-10-19/2020-10-25   9.262117
# 4  2020-10-26/2020-11-01  11.039690
# 5  2020-11-02/2020-11-08  11.576407
# 6  2020-11-09/2020-11-15  11.279120
# 7  2020-11-16/2020-11-22  12.251439
# 8  2020-11-23/2020-11-29  13.032881
# 9  2020-11-30/2020-12-06   7.493116

# %%
dp["count"].sum()
# Out:
# 100.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure 'year_week' is in the same format (assuming it's a string)
df1['year_week'] = df1['year_week'].astype(str)
df2['year_week'] = df2['year_week'].astype(str)
dp['year_week'] = dp['year_week'].astype(str)

# Extend dp to match the range of weeks in df1
all_weeks = df1['year_week']

# Reindex dp to match the weeks in df1
dp_extended = dp.set_index('year_week').reindex(all_weeks).reset_index()

# Fill missing values with 0
dp_extended['count'] = dp_extended['count'].fillna(0)

# Identify the original and extended parts for Twitter
dp_original_weeks = dp['year_week'].unique()

# Plotting
plt.figure(figsize=(16, 6))

# Plot df1 (Dotwin) as a line graph
plt.plot(df1['year_week'], df1['count'], label='Dotwin', linestyle='-', marker='o', color='blue')

# Plot df2 (Parler) as a line graph
plt.plot(df2['year_week'], df2['count'], label='Parler', linestyle='-', marker='o', color='green')

# First plot the Twitter data as grey for both original and extended parts
plt.plot(dp_extended['year_week'], dp_extended['count'], linestyle='-', marker='o', color='black')

# Then, overlay the original Twitter data in red, maintaining the continuity of the line
plt.plot(dp_extended[dp_extended['year_week'].isin(dp_original_weeks)]['year_week'], 
         dp_extended[dp_extended['year_week'].isin(dp_original_weeks)]['count'], 
         linestyle='-', marker='o', color='orange')

# Add labels and title
plt.xlabel('Year Week')
plt.ylabel('Percentage of comments')
plt.title('Comments over Time (Line Graph)')

# Add legend
plt.legend(['Dotwin', 'Parler', 'Twitter (Extended)', 'Twitter (Original)'])

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)
plt.grid(True)
# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example DataFrames (replace with actual data)


# Plotting
plt.figure(figsize=(16, 6))

# Plot df1 as a line graph
plt.plot(df1['year_week'].astype(str), df1['count'], label='Dotwin', linestyle='-', marker='o')

# Plot df2 as a line graph
plt.plot(df2['year_week'].astype(str), df2['count'], label='Parler', linestyle='-', marker='o')
plt.plot(dp['year_week'].astype(str), dp['count'], label='Twitter', linestyle='-', marker='o')

# Add labels and title
plt.xlabel('Year Week')
plt.ylabel('Percentage of comments')  # Changed the label to "Percentage"
plt.title('Comments over Time (Line Graph)')

# Add legend
plt.legend()

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)
plt.grid(True)
# Show plot
plt.tight_layout()
plt.show()
